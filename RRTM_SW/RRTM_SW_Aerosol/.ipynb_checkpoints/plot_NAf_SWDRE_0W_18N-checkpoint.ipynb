# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
from netCDF4 import Dataset

# %%
import read_output_rrtm
import Kevin_read_output_rrtm

# %%
# !pip install basemap
# Out:
# Requirement already satisfied: basemap in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (1.4.1)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from basemap) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.9,>=1.5 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from basemap) (3.8.3)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from basemap) (3.6.1)
# Requirement already satisfied: packaging<24.0,>=16.0 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from basemap) (23.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from basemap) (1.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from matplotlib<3.9,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/rrtm_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import sys
from netCDF4 import Dataset
from scipy import stats
from mpl_toolkits.basemap import Basemap  #need to install manually by using '!pip install basemap'
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# # Dust optical properties 0W, 18N Results

# %% [markdown]
# ## Download North African dust optical properties 0W, 18N results

# %%
NAf_0W_18N_TOA = np.loadtxt('NAf_0W_18N_TOA_file_shrink.txt', skiprows=1)
NAf_0W_18N_seas = []
NAf_0W_18N_lat = []
NAf_0W_18N_lon = []
NAf_0W_18N_Rs = []
NAf_0W_18N_sza = []
NAf_0W_18N_aerosol = []
NAf_0W_18N_clear = []
NAf_0W_18N_net = []
NAf_0W_18N_net_daod = 0.622

for i in range(len(NAf_0W_18N_TOA)):
    NAf_0W_18N_seas.append(NAf_0W_18N_TOA[i][0])
    NAf_0W_18N_lat.append(NAf_0W_18N_TOA[i][1])
    NAf_0W_18N_lon.append(NAf_0W_18N_TOA[i][2])
    NAf_0W_18N_Rs.append(NAf_0W_18N_TOA[i][3])
    NAf_0W_18N_sza.append(NAf_0W_18N_TOA[i][4])
    NAf_0W_18N_aerosol.append(NAf_0W_18N_TOA[i][5])
    NAf_0W_18N_clear.append(NAf_0W_18N_TOA[i][6])
    NAf_0W_18N_net.append(NAf_0W_18N_TOA[i][7])

# %%
NAf_0W_18N_seas = np.array(NAf_0W_18N_seas)
print(NAf_0W_18N_seas.shape)
# Out:
# (2772,)

# %%
NAf_0W_18N_seas = np.array(NAf_0W_18N_seas)
print(NAf_0W_18N_seas.shape)
NAf_0W_18N_lat = np.array(NAf_0W_18N_lat)
print(NAf_0W_18N_lat.shape)
NAf_0W_18N_lon = np.array(NAf_0W_18N_lon)
print(NAf_0W_18N_lon.shape)

NAf_0W_18N_Rs = np.array(NAf_0W_18N_Rs)
print(NAf_0W_18N_Rs.shape)
NAf_0W_18N_sza = np.array(NAf_0W_18N_sza)
print(NAf_0W_18N_sza.shape)
NAf_0W_18N_aerosol = np.array(NAf_0W_18N_aerosol)
print(NAf_0W_18N_aerosol.shape)
NAf_0W_18N_clear = np.array(NAf_0W_18N_clear)
print(NAf_0W_18N_clear.shape)
NAf_0W_18N_net = np.array(NAf_0W_18N_net)
print(NAf_0W_18N_net.shape)
# Out:
# (2772,)
# (2772,)
# (2772,)
# (2772,)
# (2772,)
# (2772,)
# (2772,)
# (2772,)

# %%
len(np.unique(NAf_0W_18N_lat))
# Out:
# 21

# %%
len(np.unique(NAf_0W_18N_lon))
# Out:
# 33

# %%
NAf_SWDRE_array = np.zeros((4,len(np.unique(NAf_0W_18N_lat)),len(np.unique(NAf_0W_18N_lon))))
lat_coord = np.unique(NAf_0W_18N_lat)                           
lon_coord = np.unique(NAf_0W_18N_lon)

for i in range(len(NAf_0W_18N_TOA)):
    for iseas in range(0,4):
        for ilat in range(len(np.unique(NAf_0W_18N_lat))):
            for ilon in range(len(np.unique(NAf_0W_18N_lon))):
                if iseas == NAf_0W_18N_seas[i] and lat_coord[ilat] == NAf_0W_18N_lat[i]and lon_coord[ilon] == NAf_0W_18N_lon[i]:                            
                    NAf_SWDRE_array[iseas,ilat,ilon] = NAf_0W_18N_net[i]

# %%
NAf_SWDRE_array[0].shape
# Out:
# (21, 33)

# %% [markdown]
# ## Plot North African dust SW DRE w/ 0W_18N dust optical properties

# %%
#define lon lat boundaries for map plot
lon_bds = np.arange(min(NAf_0W_18N_lon),max(NAf_0W_18N_lon) +0.1 ,2.5)  # longitude grid boundaries (DustCOMM DATA)
lat_bds = np.arange(min(NAf_0W_18N_lat),max(NAf_0W_18N_lat) +0.1,1.89)   # latitude grid boundaries (DustCOMM DATA)
print(len(lon_bds)) #32
print(len(lat_bds)) #22

bounds_swdre = np.arange(-6,6.1,0.1)
norm_swdre  = colors.BoundaryNorm(boundaries = bounds_swdre, ncolors = 256)
##Sahara Only: 10W, 30E lattiutude and 15N-30N and longitude
#----------
#Global Map of Monthly Mean DRE_SW of North African Dust
#----------

fig,ax = plt.subplots(1,4,figsize=(18,10))
fig.patch.set_facecolor('white')
map = Basemap(llcrnrlon = -30, llcrnrlat = 0, urcrnrlon = 50, urcrnrlat = 40)

Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3
seasons=np.array(['DJF','MAM','JJA','SON'])

#Plot bulk Norh Athfrican dust SW DRE by season

fig_arrangement = [ax[0] ,ax[1], ax[2], ax[3]]
plt.title('North African Dust')
number_of_seasons = [0,1,2,3]
for i in number_of_seasons:
    axis=fig_arrangement[i]
    map.drawcoastlines(ax=axis)
    map.drawparallels(np.arange(-90.,90.,30.),labels=[True,False,False,False],ax=axis,fontsize=10)
    map.drawmeridians(np.arange(-180.,180.,60.),labels=[False,False,False,True],ax=axis,fontsize=10)
    cs00=map.pcolormesh(Lon,Lat,NAf_SWDRE_array[i],cmap=plt.get_cmap('RdBu_r'),norm=norm_swdre,ax=axis)
    axis.set_title('NAf (rrtm) Dust TOA SW DRE ({:s})'.format(seasons[i]),fontsize=12,fontweight='bold')
    axis.set_aspect(aspect)

cmap=plt.get_cmap('RdBu_r')
cmap.set_bad(color='grey')

#****Colorbar
# getting the lower left (x0,y0) and upper right (x1,y1) corners:
[[x00,y00],[x01,y01]] = ax[0].get_position().get_points()
[[x10,y10],[x11,y11]] = ax[3].get_position().get_points()
pad = 0.02; width = 0.01
cbar_ax = fig.add_axes([x11+pad, y10, width, y01-y10])
axcb = fig.colorbar(cs00, cax=cbar_ax,extend='both',ticks=np.array([-6,-4,-2,0,2,4,6]))
axcb.ax.tick_params(labelsize=12)
axcb.set_label('SW DRE [W$m^-2$]')
# Out:
# 33
# 21
# /var/folders/47/97wl1v310zqcw6zy080_r_8r0000gs/T/ipykernel_1357/3222333530.py:37: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdBu_r").copy()
#   cmap.set_bad(color='grey')

# %% [markdown]
# ## Divide by rrtm column DAOD Plot North African dust SW DREE w/ 0W_18N dust optical properties

# %%
#DREE -- divide by rrtm colyumn daod
NAf_0W_18N_net_daod = 0.622
NAf_SWDREE_array = NAf_SWDRE_array/NAf_0W_18N_net_daod
#define lon lat boundaries for map plot
lon_bds = np.arange(min(NAf_0W_18N_lon),max(NAf_0W_18N_lon) +0.1 ,2.5)  # longitude grid boundaries (DustCOMM DATA)
lat_bds = np.arange(min(NAf_0W_18N_lat),max(NAf_0W_18N_lat) +0.1,1.89)   # latitude grid boundaries (DustCOMM DATA)
print(len(lon_bds)) #32
print(len(lat_bds)) #22

bounds_swdre = np.arange(-6,6.1,0.1)
norm_swdre  = colors.BoundaryNorm(boundaries = bounds_swdre, ncolors = 256)
##Sahara Only: 10W, 30E lattiutude and 15N-30N and longitude
#----------
#Global Map of Monthly Mean DRE_SW of North African Dust
#----------

fig,ax = plt.subplots(1,4,figsize=(18,10))
fig.patch.set_facecolor('white')
map = Basemap(llcrnrlon = -30, llcrnrlat = 0, urcrnrlon = 50, urcrnrlat = 40)

Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3
seasons=np.array(['DJF','MAM','JJA','SON'])

#Plot bulk Norh Athfrican dust SW DRE by season

fig_arrangement = [ax[0] ,ax[1], ax[2], ax[3]]
plt.title('North African Dust')
number_of_seasons = [0,1,2,3]
for i in number_of_seasons:
    axis=fig_arrangement[i]
    map.drawcoastlines(ax=axis)
    map.drawparallels(np.arange(-90.,90.,30.),labels=[True,False,False,False],ax=axis,fontsize=10)
    map.drawmeridians(np.arange(-180.,180.,60.),labels=[False,False,False,True],ax=axis,fontsize=10)
    cs00=map.pcolormesh(Lon,Lat,NAf_SWDREE_array[i],cmap=plt.get_cmap('RdBu_r'),norm=norm_swdre,ax=axis)
    axis.set_title('NAf Dust TOA SW DREE ({:s})'.format(seasons[i]),fontsize=12,fontweight='bold')
    axis.set_aspect(aspect)

cmap=plt.get_cmap('RdBu_r')
cmap.set_bad(color='grey')

#****Colorbar
# getting the lower left (x0,y0) and upper right (x1,y1) corners:
[[x00,y00],[x01,y01]] = ax[0].get_position().get_points()
[[x10,y10],[x11,y11]] = ax[3].get_position().get_points()
pad = 0.02; width = 0.01
cbar_ax = fig.add_axes([x11+pad, y10, width, y01-y10])
axcb = fig.colorbar(cs00, cax=cbar_ax,extend='both',ticks=np.array([-10,-8,-6,-4,-2,0,2,4,6,8,10]))
axcb.ax.tick_params(labelsize=12)
axcb.set_label('SW DREE [W$m^-2$]')
# Out:
# 33
# 21
# /var/folders/47/97wl1v310zqcw6zy080_r_8r0000gs/T/ipykernel_1357/2593803728.py:40: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdBu_r").copy()
#   cmap.set_bad(color='grey')

# %% [markdown]
# ## Multiply North African DRE by DustCOMM DAOD --dust optical properties 0W, 18N

# %%
daod_Dustcomm_PM20_Dataset = Dataset('../../Dust_Optical_Properties/DustCOMM_source_region_DAOD_seas_bin_abs.nc')
print(daod_Dustcomm_PM20_Dataset) #[lat,lon,bin,source,season]

lat_Dustcomm_PM20 = np.array(daod_Dustcomm_PM20_Dataset.variables['lat'][:])
lon_Dustcomm_PM20 = np.array(daod_Dustcomm_PM20_Dataset.variables['lon'][:])
mean_Daod_Dustcomm_20PM = np.array(daod_Dustcomm_PM20_Dataset.variables['Mean'][:])
#dustcomm_seas = np.array(daod_Dustcomm_PM20_Dataset.variables['season'][:])
print(mean_Daod_Dustcomm_20PM.shape)

sum_North_African_Mean_Daod_20PM = (mean_Daod_Dustcomm_20PM[:,:,:,0,:] +mean_Daod_Dustcomm_20PM[:,:,:,1,:] +mean_Daod_Dustcomm_20PM[:,:,:,2,:])
print(sum_North_African_Mean_Daod_20PM.shape)

bulk_NAf_daod = np.zeros((96,144,4))
for ilat in range(len(lat_Dustcomm_PM20)):
    for ilon in range(len(lon_Dustcomm_PM20)):
        for iseas in range(4):
            bulk_NAf_daod[ilat,ilon,iseas] = np.nansum(sum_North_African_Mean_Daod_20PM[ilat,ilon,:,iseas])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): season(4), source(9), diameter(6), lat(96), lon(144), bin(6)
#     variables(dimensions): float64 season(season), float64 source(source), float64 bin_D_lower(diameter), float64 bin_D_upper(diameter), float64 lat(lat), float64 lon(lon), float64 Median(lat, lon, bin, source, season), float64 Mean(lat, lon, bin, source, season), float64 Neg1sigma(lat, lon, bin, source, season), float64 Pos1sigman(lat, lon, bin, source, season), float64 Neg2sigma(lat, lon, bin, source, season), float64 Pos2sigma(lat, lon, bin, source, season)
#     groups:
# (96, 144, 6, 9, 4)
# (96, 144, 6, 4)

# %%
bulk_NAf_daod
# Out:
# array([[[1.19239140e-04, 1.66688941e-05, 1.78435972e-05, 1.69600163e-05],
#         [1.19239140e-04, 1.66688941e-05, 1.78435972e-05, 1.69600163e-05],
#         [1.19239140e-04, 1.66688941e-05, 1.78435972e-05, 1.69600163e-05],
#         ...,
#         [1.19239140e-04, 1.66688941e-05, 1.78435972e-05, 1.69600163e-05],
#         [1.19239141e-04, 1.66688941e-05, 1.78435977e-05, 1.69600167e-05],
#         [1.19239140e-04, 1.66688939e-05, 1.78435964e-05, 1.69600162e-05]],
#
#        [[1.14869480e-04, 1.60412650e-05, 1.69014952e-05, 1.38913246e-05],
#         [1.14869503e-04, 1.60397257e-05, 1.69126918e-05, 1.38828359e-05],
#         [1.14841997e-04, 1.60389151e-05, 1.69353147e-05, 1.38810606e-05],
#         ...,
#         [1.15002286e-04, 1.60450879e-05, 1.68791195e-05, 1.39054255e-05],
#         [1.14936158e-04, 1.60393185e-05, 1.68752127e-05, 1.39010909e-05],
#         [1.14955235e-04, 1.60314050e-05, 1.68371125e-05, 1.38634766e-05]],
#
#        [[1.18758150e-04, 1.65284372e-05, 1.80740212e-05, 1.45863649e-05],
#         [1.21089941e-04, 1.66842624e-05, 1.82185843e-05, 1.46711589e-05],
#         [1.27164769e-04, 1.70404339e-05, 1.84108485e-05, 1.47634486e-05],
#         ...,
#         [1.19488179e-04, 1.64994959e-05, 1.79025015e-05, 1.44230999e-05],
#         [1.19464039e-04, 1.65100242e-05, 1.79255134e-05, 1.44644057e-05],
#         [1.18896441e-04, 1.64528783e-05, 1.78592937e-05, 1.43439295e-05]],
#
#        ...,
#
#        [[2.23849467e-03, 5.85040174e-03, 1.76266616e-03, 1.47167000e-03],
#         [2.23343392e-03, 5.84643819e-03, 1.75951582e-03, 1.47001485e-03],
#         [2.22004831e-03, 5.83441812e-03, 1.74656179e-03, 1.46621408e-03],
#         ...,
#         [2.24358231e-03, 5.85515281e-03, 1.76301137e-03, 1.47774637e-03],
#         [2.24246555e-03, 5.85370088e-03, 1.76250084e-03, 1.47597378e-03],
#         [2.24345424e-03, 5.85376839e-03, 1.76630065e-03, 1.47773930e-03]],
#
#        [[2.17269242e-03, 5.79039101e-03, 1.82846261e-03, 1.41691099e-03],
#         [2.17153611e-03, 5.79108658e-03, 1.82862560e-03, 1.41550401e-03],
#         [2.17049802e-03, 5.79016556e-03, 1.82923208e-03, 1.41380510e-03],
#         ...,
#         [2.17303852e-03, 5.78454208e-03, 1.82342715e-03, 1.41954825e-03],
#         [2.17219433e-03, 5.78580841e-03, 1.82633881e-03, 1.41799626e-03],
#         [2.16921518e-03, 5.77883970e-03, 1.82146840e-03, 1.41858802e-03]],
#
#        [[2.13766859e-03, 5.91102912e-03, 2.07279955e-03, 1.51850943e-03],
#         [2.13766859e-03, 5.91102912e-03, 2.07279955e-03, 1.51850943e-03],
#         [2.13766859e-03, 5.91102910e-03, 2.07279955e-03, 1.51850943e-03],
#         ...,
#         [2.13766859e-03, 5.91102912e-03, 2.07279955e-03, 1.51850943e-03],
#         [2.13766859e-03, 5.91102910e-03, 2.07279956e-03, 1.51850943e-03],
#         [2.13766856e-03, 5.91102920e-03, 2.07279955e-03, 1.51850945e-03]]])

# %%
len(lat_Dustcomm_PM20[48:69])
shrink_lat_Dustcomm_PM20 = lat_Dustcomm_PM20[48:69]

# %%
len(lon_Dustcomm_PM20[59:92])
shrink_lon_Dustcomm_PM20 = lon_Dustcomm_PM20[59:92]

shrink_bulk_NAf_daod = bulk_NAf_daod[48:69,59:92,:]
shrink_bulk_NAf_daod.shape
# Out:
# (21, 33, 4)

# %%
np.max(shrink_bulk_NAf_daod)
# Out:
# 0.7372081776004925

# %% [markdown]
# ## Calculate Seasonal DustCOMM SW DRE of North African dust with dust optical properties 0W, 18N

# %%
DustCOMM_NAf_DRE = np.zeros((4,len(np.unique(NAf_0W_18N_lat)),len(np.unique(NAf_0W_18N_lon))))

for iseas in range(4):
    for ilat in range(len(np.unique(NAf_0W_18N_lat))):
        for ilon in range(len(np.unique(NAf_0W_18N_lon))):
                    DustCOMM_NAf_DRE[iseas,ilat,ilon] = NAf_SWDREE_array[iseas,ilat,ilon] * shrink_bulk_NAf_daod[ilat,ilon,iseas]

# %%
DustCOMM_NAf_DRE
# Out:
# array([[[-1.08519288e-01, -1.20091971e-01, -1.33906563e-01, ...,
#          -1.52478059e-02, -1.28222128e-02, -1.11938842e-02],
#         [-2.25415733e-01, -2.38691593e-01, -2.52484229e-01, ...,
#          -1.05352647e-02, -1.74450299e-02, -1.49890252e-02],
#         [-4.40981533e-01, -4.73437359e-01, -5.03544623e-01, ...,
#          -9.31688081e-03, -7.98322001e-03, -2.04914653e-02],
#         ...,
#         [-1.03791329e-01, -1.49827405e-01, -1.90998435e-01, ...,
#          -3.80242058e-01, -2.03480827e-01, -2.11353248e-01],
#         [-7.47378657e-02, -1.13496791e-01, -1.56869468e-01, ...,
#          -2.37233522e-01, -2.13802677e-01, -2.91226020e-01],
#         [-5.02066467e-02, -7.67148061e-02, -1.21574080e-01, ...,
#          -2.26209441e-01, -2.70672974e-01, -3.89642016e-01]],
#
#        [[-1.33624490e-01, -1.46614678e-01, -1.60423160e-01, ...,
#          -2.56649496e-02, -2.70606114e-02, -2.74626371e-02],
#         [-2.45156345e-01, -2.56587526e-01, -2.71258744e-01, ...,
#          -1.10300862e-02, -3.65153526e-02, -3.74804437e-02],
#         [-4.35917017e-01, -4.62027989e-01, -4.87429775e-01, ...,
#          -6.92878468e-03, -5.71889807e-03, -4.85504288e-02],
#         ...,
#         [-5.04477145e-02, -5.48503910e-02, -6.63834749e-02, ...,
#          -3.52892619e-01, -3.20500099e-01, -3.42203680e-01],
#         [-4.29804476e-02, -4.62348016e-02, -5.58049689e-02, ...,
#          -4.10321378e-01, -3.19309745e-01, -5.28498818e-01],
#         [-4.24209567e-02, -4.43377961e-02, -4.84628271e-02, ...,
#          -3.37496542e-01, -4.28837682e-01, -7.60054666e-01]],
#
#        [[-7.95891897e-02, -8.54182056e-02, -9.02354846e-02, ...,
#          -2.57073395e-02, -2.60935995e-02, -2.58412056e-02],
#         [-9.56592298e-02, -1.02352828e-01, -1.10857478e-01, ...,
#          -1.56126010e-02, -3.74675601e-02, -3.71875316e-02],
#         [-1.22300065e-01, -1.31102393e-01, -1.37681453e-01, ...,
#          -1.27120908e-02, -9.90855739e-03, -5.08587258e-02],
#         ...,
#         [-4.53290708e-02, -4.96251799e-02, -5.31510805e-02, ...,
#          -6.20834894e-04, -1.19772113e-02, -1.91211676e-02],
#         [-3.73118519e-02, -3.92998684e-02, -4.35153811e-02, ...,
#          -3.64242410e-02, -1.48026641e-02, -4.35764754e-02],
#         [-3.20543212e-02, -3.13376088e-02, -3.40877543e-02, ...,
#          -2.59094012e-02, -3.11659530e-02, -8.37231030e-02]],
#
#        [[-1.49257879e-02, -1.71678230e-02, -1.96209392e-02, ...,
#          -3.39347238e-03, -3.75140221e-03, -4.06621098e-03],
#         [-1.94085028e-02, -2.30491129e-02, -2.69550122e-02, ...,
#          -1.65152962e-03, -5.25437406e-03, -5.67839794e-03],
#         [-4.01302705e-02, -4.63918726e-02, -5.31439185e-02, ...,
#          -1.15682662e-03, -6.68000911e-04, -7.63162383e-03],
#         ...,
#         [-6.23852385e-02, -6.30980566e-02, -6.56102888e-02, ...,
#          -7.61959653e-02, -6.38009385e-02, -6.68520850e-02],
#         [-4.34151913e-02, -4.58685171e-02, -5.33591079e-02, ...,
#          -9.65892093e-02, -6.62797714e-02, -1.07945349e-01],
#         [-3.60351427e-02, -4.05693241e-02, -4.89279650e-02, ...,
#          -7.88662372e-02, -9.75221310e-02, -1.53666125e-01]]])

# %%
DustCOMM_NAf_DRE
#define lon lat boundaries for map plot
lon_bds = np.arange(min(NAf_0W_18N_lon),max(NAf_0W_18N_lon) +0.1 ,2.5)  # longitude grid boundaries (DustCOMM DATA)
lat_bds = np.arange(min(NAf_0W_18N_lat),max(NAf_0W_18N_lat) +0.1,1.89)   # latitude grid boundaries (DustCOMM DATA)
print(len(lon_bds)) #32
print(len(lat_bds)) #22

bounds_swdre = np.arange(-6,6.1,0.06)
norm_swdre  = colors.BoundaryNorm(boundaries = bounds_swdre, ncolors = 256)
##Sahara Only: 10W, 30E lattiutude and 15N-30N and longitude
#----------
#Global Map of Monthly Mean DRE_SW of North African Dust
#----------

fig,ax = plt.subplots(1,4,figsize=(18,10))
fig.patch.set_facecolor('white')
map = Basemap(llcrnrlon = -30, llcrnrlat = 0, urcrnrlon = 50, urcrnrlat = 40)


Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3
seasons=np.array(['DJF','MAM','JJA','SON'])

#Plot bulk Norh Athfrican dust SW DRE by season

fig_arrangement = [ax[0] ,ax[1], ax[2], ax[3]]
plt.title('North African Dust')
number_of_seasons = [0,1,2,3]
for i in number_of_seasons:
    axis=fig_arrangement[i]
    map.drawcoastlines(ax=axis)
    map.drawparallels(np.arange(-90.,90.,30.),labels=[True,False,False,False],ax=axis,fontsize=10)
    map.drawmeridians(np.arange(-180.,180.,60.),labels=[False,False,False,True],ax=axis,fontsize=10)
    cs00=map.pcolormesh(Lon,Lat, DustCOMM_NAf_DRE[i],cmap=plt.get_cmap('RdBu_r'),norm=norm_swdre,ax=axis)
    axis.set_title('NAf (DustCOMM) TOA SW DRE ({:s})'.format(seasons[i]),fontsize=12,fontweight='bold')
    axis.set_aspect(aspect)

cmap=plt.get_cmap('RdBu_r')
cmap.set_bad(color='grey')

#****Colorbar
# getting the lower left (x0,y0) and upper right (x1,y1) corners:
[[x00,y00],[x01,y01]] = ax[0].get_position().get_points()
[[x10,y10],[x11,y11]] = ax[3].get_position().get_points()
pad = 0.02; width = 0.01
cbar_ax = fig.add_axes([x11+pad, y10, width, y01-y10])
axcb = fig.colorbar(cs00, cax=cbar_ax,extend='both',ticks=np.array([-6,-4,-2,0,2,4,6]))
axcb.ax.tick_params(labelsize=12)
axcb.set_label('SW DRE [W$m^-2$]')
# Out:
# 33
# 21
# /var/folders/47/97wl1v310zqcw6zy080_r_8r0000gs/T/ipykernel_1357/1470554685.py:39: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdBu_r").copy()
#   cmap.set_bad(color='grey')

# %% [markdown]
# ## Annual DAOD plot

# %%
#define lon lat boundaries for map plot
lon_bds = np.arange(min(NAf_0W_18N_lon),max(NAf_0W_18N_lon) +0.1 ,2.5)  # longitude grid boundaries (DustCOMM DATA)
lat_bds = np.arange(min(NAf_0W_18N_lat),max(NAf_0W_18N_lat) +0.1,1.89)   # latitude grid boundaries (DustCOMM DATA)
print(len(lon_bds)) #32
print(len(lat_bds)) #22

bounds_swdre = np.arange(-1,1.1,0.01)
norm_swdre  = colors.BoundaryNorm(boundaries = bounds_swdre, ncolors = 256)
##Sahara Only: 10W, 30E lattiutude and 15N-30N and longitude
#----------
#Global Map of Monthly Mean DRE_SW of North African Dust
#----------

fig,ax = plt.subplots(1,4,figsize=(18,10))
fig.patch.set_facecolor('white')
map = Basemap(llcrnrlon = -30, llcrnrlat = 0, urcrnrlon = 50, urcrnrlat = 40)


Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3
seasons=np.array(['DJF','MAM','JJA','SON'])

#Plot bulk Norh Athfrican dust SW DRE by season

fig_arrangement = [ax[0] ,ax[1], ax[2], ax[3]]
plt.title('North African Dust')
number_of_seasons = [0,1,2,3]
for i in number_of_seasons:
    axis=fig_arrangement[i]
    map.drawcoastlines(ax=axis)
    map.drawparallels(np.arange(-90.,90.,30.),labels=[True,False,False,False],ax=axis,fontsize=10)
    map.drawmeridians(np.arange(-180.,180.,60.),labels=[False,False,False,True],ax=axis,fontsize=10)
    cs00=map.pcolormesh(Lon,Lat, shrink_bulk_NAf_daod[:,:,i],cmap=plt.get_cmap('RdBu_r'),norm=norm_swdre,ax=axis)
    axis.set_title('NAf (DustCOMM) TOA DAOD ({:s})'.format(seasons[i]),fontsize=12,fontweight='bold')
    axis.set_aspect(aspect)

cmap=plt.get_cmap('RdBu_r')
cmap.set_bad(color='grey')

#****Colorbar
# getting the lower left (x0,y0) and upper right (x1,y1) corners:
[[x00,y00],[x01,y01]] = ax[0].get_position().get_points()
[[x10,y10],[x11,y11]] = ax[3].get_position().get_points()
pad = 0.02; width = 0.01
cbar_ax = fig.add_axes([x11+pad, y10, width, y01-y10])
axcb = fig.colorbar(cs00, cax=cbar_ax,extend='both',ticks=np.array([-1,0,1]))
axcb.ax.tick_params(labelsize=12)
axcb.set_label('SW DAOD')
# Out:
# 33
# 21
# /var/folders/47/97wl1v310zqcw6zy080_r_8r0000gs/T/ipykernel_1357/1149625041.py:38: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdBu_r").copy()
#   cmap.set_bad(color='grey')

# %%
annual_avg_DAOD = np.zeros((len(bulk_NAf_daod[:,0,0]),len(bulk_NAf_daod[0,:,0])))

for ilat in range(len(bulk_NAf_daod[:,0,0])):
    for ilon in range(len(bulk_NAf_daod[0,:,0])):
        annual_avg_DAOD[ilat,ilon] = np.mean(bulk_NAf_daod[ilat,ilon,:])
print(annual_avg_DAOD.shape)
# Out:
# (96, 144)

# %%
#define lon lat boundaries for map plot
lon_bds = np.arange(-180,180,2.5)  # longitude grid boundaries (CALIOP DATA)
lat_bds = np.arange(-90,90.1,1.89)   # latitude grid boundaries (CALIOP DATA)


bounds_swdre = np.arange(-0.75,0.75,0.01)
norm_swdre  = colors.BoundaryNorm(boundaries = bounds_swdre, ncolors = 256)
#----------
#Global Map of Monthly Mean DREE_SW of North African Dust
#----------

#Plot DRE annual average 

fig,ax = plt.subplots(1,1,figsize=(8,5))
fig.patch.set_facecolor('white')
map = Basemap(llcrnrlon = -180, llcrnrlat = -90, urcrnrlon = 180, urcrnrlat = 90)

Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3

#Plot DRE bin averaged by month 
fig_arrangement = ax #[0,0]

axis= fig_arrangement
map.drawcoastlines(ax=axis)
map.drawparallels(np.arange(-90.,90.,30.),labels=[True,False,False,False],ax=axis,fontsize=10)
map.drawmeridians(np.arange(-180.,180.,60.),labels=[False,False,False,True],ax=axis,fontsize=10)
cs00=map.pcolormesh(Lon,Lat,annual_avg_DAOD,cmap=plt.get_cmap('RdBu_r'),norm=norm_swdre,ax=axis)
axis.set_title('North African Dust Annual SW DAOD TOA',fontsize=12,fontweight='bold')
axis.set_aspect(aspect)

cmap = plt.cm.get_cmap("RdBu_r").copy()
cmap.set_bad(color='grey')

#****Colorbar
# getting the lower left (x0,y0) and upper right (x1,y1) corners:
[[x00,y00],[x01,y01]] = ax.get_position().get_points()
[[x10,y10],[x11,y11]] = ax.get_position().get_points()
pad = 0.02; width = 0.01
cbar_ax = fig.add_axes([x11+pad, y10, width, y01-y10])
axcb = fig.colorbar(cs00, cax=cbar_ax,extend='both',ticks=np.array([-0.75,-0.5,-0.25,0,0.25,0.5,0.75]))
axcb.ax.tick_params(labelsize=12)
axcb.set_label('SW DAOD')

# %% [markdown]
# ## Calculate + plot SW DRE NAf Dust annual average with dust optical properties at 0W_18N

# %%
NAf_SWDRE_annual_avg = np.zeros((len(np.unique(NAf_0W_18N_lat)),len(np.unique(NAf_0W_18N_lon))))
for ilat in range(len(np.unique(NAf_0W_18N_lat))):
    for ilon in range(len(np.unique(NAf_0W_18N_lon))):
        NAf_SWDRE_annual_avg[ilat,ilon] = np.average(DustCOMM_NAf_DRE[:,ilat,ilon])

# %%
lon_bds = np.arange(min(NAf_0W_18N_lon),max(NAf_0W_18N_lon) +0.1 ,2.5)  # longitude grid boundaries (DustCOMM DATA)
lat_bds = np.arange(min(NAf_0W_18N_lat),max(NAf_0W_18N_lat) +0.1,1.89)   # latitude grid boundaries (DustCOMM DATA)
print(len(lon_bds)) #32
print(len(lat_bds)) #22

bounds_swdre = np.arange(-6,6.1,0.1)
norm_swdre  = colors.BoundaryNorm(boundaries = bounds_swdre, ncolors = 256)
##Sahara Only: 10W, 30E lattiutude and 15N-30N and longitude
#----------
#Global Map of Monthly Mean DRE_SW of North African Dust
#----------

map = Basemap(llcrnrlon = -180, llcrnrlat = -90, urcrnrlon = 180, urcrnrlat = 90)

Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3

#Plot DRE annual average 

fig,ax = plt.subplots(1,1,figsize=(18,10))
fig.patch.set_facecolor('white')
#map = Basemap(llcrnrlon = -180, llcrnrlat = -90, urcrnrlon = 180, urcrnrlat = 90)
map = Basemap(llcrnrlon=-30, llcrnrlat=0, urcrnrlon=50, urcrnrlat=40)
Lon,Lat = map(lon_bds,lat_bds)   
aspect=1.3

#Plot DRE bin averaged by month 
fig_arrangement = ax #[0,0]

dree_range = ['Min RI', 'Mean RI', 'Max RI']

axis= fig_arrangement
map.drawcoastlines(ax=axis)
cs00 = map.pcolormesh(Lon, Lat, NAf_SWDRE_annual_avg, cmap=plt.get_cmap('RdBu_r'), norm=norm_swdre, ax=ax)
map.drawparallels(np.arange(-90.,90.,30.),labels=[True,False,False,False],ax=axis,fontsize=10)
map.drawmeridians(np.arange(-180.,180.,60.),labels=[False,False,False,True],ax=axis,fontsize=10)
ax.set_title('NAf (DustCOMM) Dust Annual SW DRE TOA', fontsize=12, fontweight='bold')
ax.set_aspect(aspect)

cmap = plt.cm.get_cmap("RdBu_r").copy()
cmap.set_bad(color='grey')

#****Colorbar
# getting the lower left (x0,y0) and upper right (x1,y1) corners:
[[x00, y00], [x01, y01]] = ax.get_position().get_points()
[[x10, y10], [x11, y11]] = ax.get_position().get_points()
pad = 0.02; width = 0.01
cbar_ax = fig.add_axes([x11 + pad, y10, width, y01 - y10])
axcb = fig.colorbar(cs00, cax=cbar_ax, extend='both', ticks=np.array([-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10]))
axcb.ax.tick_params(labelsize=12)
axcb.set_label('SW DRE [W$m^-2$]')

plt.show()
# Out:
# 33
# 21

# %%
#from funct_call import deg2rad

def deg2rad(deg):
    rad = deg*np.pi/180
    return(rad)

llon,llat = np.meshgrid(np.unique(NAf_0W_18N_lon),np.unique(NAf_0W_18N_lat))

SW_DRE_Naf_dust_global_avg = np.average(NAf_SWDRE_annual_avg, weights = np.cos(deg2rad(llat)))
print(SW_DRE_Naf_dust_global_avg )
# Out:
# -0.22517041905436594

# %%
NAf_SWDRE_annual_avg.shape
# Out:
# (21, 33)

# %%
song_sw_dree_dre = np.load('song_sw_dree_dre.npy')
print(song_sw_dree_dre.shape)
# Out:
# (21, 43)

# %%
SW_DRE_Naf_dust_global_avg = np.average(song_sw_dree_dre, weights = np.cos(deg2rad(llat)), axis=0)
print(SW_DRE_Naf_dust_global_avg )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 SW_DRE_Naf_dust_global_avg = np.average(song_sw_dree_dre, weights = np.cos(deg2rad(llat)), axis=0)
#       2 print(SW_DRE_Naf_dust_global_avg )
#
# File <__array_function__ internals>:5, in average(*args, **kwargs)
#
# File /opt/anaconda3/envs/basemapenv/lib/python3.8/site-packages/numpy/lib/function_base.py:397, in average(a, axis, weights, returned)
#     393     raise TypeError(
#     394         "Axis must be specified when shapes of a and weights "
#     395         "differ.")
#     396 if wgt.ndim != 1:
# --> 397     raise TypeError(
#     398         "1D weights expected when shapes of a and weights differ.")
#     399 if wgt.shape[0] != a.shape[axis]:
#     400     raise ValueError(
#     401         "Length of weights not compatible with specified axis.")
#
# TypeError: 1D weights expected when shapes of a and weights differ.
