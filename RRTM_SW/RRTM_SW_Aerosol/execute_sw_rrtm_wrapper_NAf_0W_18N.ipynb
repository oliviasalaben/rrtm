# %% [markdown]
# """
# Module: Run SW RRTM Wrapper (sw_rrtm_wrapper.ipynb)
#
# Created on 2024
#
# @authors: Olivia Salaben and Jianyu Zheng
# """

# %%
import numpy as np
from netCDF4 import Dataset

# %%
#----------
# Import Ashok's isolation weighted solar zenith angle (SZA) data from 2006
#----------

sza_Dataset = Dataset('Albedo_and_sza_data/inso_weighted_SZA_seasonal_DustCOMMgrid.nc')
print(sza_Dataset) #[DJF, JJA, MAM, SON,lat,lon]

lat_sza = np.array(sza_Dataset.variables['lat'][:])
lon_sza = np.array(sza_Dataset.variables['lon'][:])
sza_weighted_DJF = np.array(sza_Dataset.variables['isza_DJF'][:])
sza_weighted_JJA = np.array(sza_Dataset.variables['isza_JJA'][:])
sza_weighted_MAM = np.array(sza_Dataset.variables['isza_MAM'][:])
sza_weighted_SON = np.array(sza_Dataset.variables['isza_SON'][:])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): lon(144), lat(96)
#     variables(dimensions): float32 lon(lon), float32 lat(lat), float32 isza_DJF(lat, lon), float32 isza_MAM(lat, lon), float32 isza_JJA(lat, lon), float32 isza_SON(lat, lon)
#     groups:

# %%
#Re-order -180 to be +180 and move to end of array and reorder sza data to match DustCOMM coordinates order
lon_sza[lon_sza == -180] = 180
lon_sza = np.sort(lon_sza)
print(lon_sza)

sza_weighted_DJF = np.concatenate((sza_weighted_DJF[:,1:],sza_weighted_DJF[:,:1]), axis=1)
sza_weighted_MAM = np.concatenate((sza_weighted_MAM[:,1:],sza_weighted_MAM[:,:1]), axis=1)
sza_weighted_JJA = np.concatenate((sza_weighted_JJA[:,1:],sza_weighted_JJA[:,:1]), axis=1)
sza_weighted_SON = np.concatenate((sza_weighted_SON[:,1:],sza_weighted_SON[:,:1]), axis=1)

sza_weighted_all = [sza_weighted_DJF,sza_weighted_MAM,sza_weighted_JJA, sza_weighted_SON]
# Out:
# [-177.5 -175.  -172.5 -170.  -167.5 -165.  -162.5 -160.  -157.5 -155.
#  -152.5 -150.  -147.5 -145.  -142.5 -140.  -137.5 -135.  -132.5 -130.
#  -127.5 -125.  -122.5 -120.  -117.5 -115.  -112.5 -110.  -107.5 -105.
#  -102.5 -100.   -97.5  -95.   -92.5  -90.   -87.5  -85.   -82.5  -80.
#   -77.5  -75.   -72.5  -70.   -67.5  -65.   -62.5  -60.   -57.5  -55.
#   -52.5  -50.   -47.5  -45.   -42.5  -40.   -37.5  -35.   -32.5  -30.
#   -27.5  -25.   -22.5  -20.   -17.5  -15.   -12.5  -10.    -7.5   -5.
#    -2.5    0.     2.5    5.     7.5   10.    12.5   15.    17.5   20.
#    22.5   25.    27.5   30.    32.5   35.    37.5   40.    42.5   45.
#    47.5   50.    52.5   55.    57.5   60.    62.5   65.    67.5   70.
#    72.5   75.    77.5   80.    82.5   85.    87.5   90.    92.5   95.
#    97.5  100.   102.5  105.   107.5  110.   112.5  115.   117.5  120.
#   122.5  125.   127.5  130.   132.5  135.   137.5  140.   142.5  145.
#   147.5  150.   152.5  155.   157.5  160.   162.5  165.   167.5  170.
#   172.5  175.   177.5  180. ]

# %%
#Create run for all seasons
seasons = [0,1,2,3]
seas_name= ['DJF','MAM','JJA','SON']

# %%
# Read in indices where MODIS surface albedo data coordinates match DustCOMM coordinates
new_match_lat_index = np.load('new_match_lat_index.npy')
new_match_lon_index = np.load('new_match_lon_index.npy')

# %%
#Create function that exracts monthly surface albedo data from MERR2
def get_month_albedo(year, month):
    filename = f'MERRA2_400.tavgM_2d_rad_Nx.{year}{month:02}.nc4'
    dataset = Dataset('Albedo_and_sza_data/' +filename)
    albedo = np.array(dataset.variables['ALBEDO'][0])
    return albedo

albedo_2023 = []

for month in range(1, 13):
    albedo_2023.append(get_month_albedo(2023, month))

albedo_2023 = np.array(albedo_2023)

# %%
#Calculate seasonal everage of the MERR2 monthly surface albedo data for the 

DJF_merra2_albedo_2023 = np.zeros((len(new_match_lat_index),len(new_match_lon_index)))
MAM_merra2_albedo_2023 = np.zeros((len(new_match_lat_index),len(new_match_lon_index)))
JJA_merra2_albedo_2023 = np.zeros((len(new_match_lat_index),len(new_match_lon_index)))
SON_merra2_albedo_2023 = np.zeros((len(new_match_lat_index),len(new_match_lon_index)))
for ilon in range(len(new_match_lon_index)):
    for ilat in range(len(new_match_lat_index)):
        DJF_merra2_albedo_2023[ilat,ilon] = (albedo_2023[11,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[0,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[1,new_match_lat_index[ilat],new_match_lon_index[ilon]])/3
        MAM_merra2_albedo_2023[ilat,ilon] = (albedo_2023[2,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[3,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[4,new_match_lat_index[ilat],new_match_lon_index[ilon]])/3                
        JJA_merra2_albedo_2023[ilat,ilon] = (albedo_2023[5,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[6,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[7,new_match_lat_index[ilat],new_match_lon_index[ilon]])/3
        SON_merra2_albedo_2023[ilat,ilon] = (albedo_2023[8,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[9,new_match_lat_index[ilat],new_match_lon_index[ilon]] + albedo_2023[10,new_match_lat_index[ilat],new_match_lon_index[ilon]])/3
        
all_merra2_albedo_2023 = [DJF_merra2_albedo_2023, MAM_merra2_albedo_2023, JJA_merra2_albedo_2023, SON_merra2_albedo_2023]

# %%
# Loop through the values and execute the notebook with each combination
for season in seasons:
    for ilat in range(len(lat_sza)):
        for ilon in range(len(lon_sza)):
            if (lat_sza[ilat] >= 0) & (lat_sza[ilat] <= 40):
                if (lon_sza[ilon] >= -30) & (lon_sza[ilon] <= 50):
                    Rs = float(all_merra2_albedo_2023[season][ilat, ilon])
                    sza = float(sza_weighted_all[season][ilat, ilon])
                    # Remove the float conversion for season
                    season = season
                    lat = float(lat_sza[ilat])
                    lon = float(lon_sza[ilon])
                    if (lat == 12.600000381469727) and (lon == 10.00) and (season == 3):
                        Rs = 0 #np.nan 
                        sza = 0 #np.nan 
                    # Use the %store magic command to pass variables to the notebook
                    # %store Rs sza season lat lon
                    # %run sw_rrtm_wrapper.ipynb
# Out:
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07109976311524709, sza = 43.28520965576172, lat = 1.2000000476837158, lon = -30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07150321205457051, sza = 42.958072662353516, lat = 1.2000000476837158, lon = -27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07263585925102234, sza = 42.4990348815918, lat = 1.2000000476837158, lon = -25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07275480528672536, sza = 41.901248931884766, lat = 1.2000000476837158, lon = -22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07237548629442851, sza = 41.15594482421875, lat = 1.2000000476837158, lon = -20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07030485073725383, sza = 40.251094818115234, lat = 1.2000000476837158, lon = -17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06995316346486409, sza = 39.39759826660156, lat = 1.2000000476837158, lon = -15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07064072291056316, sza = 40.012733459472656, lat = 1.2000000476837158, lon = -12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0700238545735677, sza = 40.663761138916016, lat = 1.2000000476837158, lon = -10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07031916578610738, sza = 41.270931243896484, lat = 1.2000000476837158, lon = -7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06986903150876363, sza = 41.82761001586914, lat = 1.2000000476837158, lon = -5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06931610902150472, sza = 42.32533264160156, lat = 1.2000000476837158, lon = -2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06911365191141765, sza = 42.75462341308594, lat = 1.2000000476837158, lon = 0.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06885892152786255, sza = 43.105613708496094, lat = 1.2000000476837158, lon = 2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06894669433434804, sza = 43.3685188293457, lat = 1.2000000476837158, lon = 5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0693716009457906, sza = 43.53392791748047, lat = 1.2000000476837158, lon = 7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11816394329071045, sza = 43.5929069519043, lat = 1.2000000476837158, lon = 10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12862624724706015, sza = 43.53696823120117, lat = 1.2000000476837158, lon = 12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12427236636479695, sza = 43.357913970947266, lat = 1.2000000476837158, lon = 15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1175093154112498, sza = 43.04752731323242, lat = 1.2000000476837158, lon = 17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1199194888273875, sza = 42.59703063964844, lat = 1.2000000476837158, lon = 20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12625829378763834, sza = 41.99628448486328, lat = 1.2000000476837158, lon = 22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1287977695465088, sza = 41.23267364501953, lat = 1.2000000476837158, lon = 25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12742533286412558, sza = 40.289554595947266, lat = 1.2000000476837158, lon = 27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14305531978607178, sza = 39.39759826660156, lat = 1.2000000476837158, lon = 30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1467526157697042, sza = 39.97169494628906, lat = 1.2000000476837158, lon = 32.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.15523985028266907, sza = 40.57600402832031, lat = 1.2000000476837158, lon = 35.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.18613159656524658, sza = 41.15463638305664, lat = 1.2000000476837158, lon = 37.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.2119134267171224, sza = 41.69948959350586, lat = 1.2000000476837158, lon = 40.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1585682233174642, sza = 42.20051956176758, lat = 1.2000000476837158, lon = 42.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07192044456799825, sza = 42.646453857421875, lat = 1.2000000476837158, lon = 45.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07311164339383443, sza = 43.02539825439453, lat = 1.2000000476837158, lon = 47.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07526538769404094, sza = 43.32524490356445, lat = 1.2000000476837158, lon = 50.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07115377982457478, sza = 44.33875274658203, lat = 3.0999999046325684, lon = -30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07080348332722981, sza = 43.99687194824219, lat = 3.0999999046325684, lon = -27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07145652671655019, sza = 43.51969909667969, lat = 3.0999999046325684, lon = -25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0714973012606303, sza = 42.898406982421875, lat = 3.0999999046325684, lon = -22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07088850935300191, sza = 42.121864318847656, lat = 3.0999999046325684, lon = -20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07016207277774811, sza = 41.175418853759766, lat = 3.0999999046325684, lon = -17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07006224989891052, sza = 40.73384094238281, lat = 3.0999999046325684, lon = -15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06980369488398235, sza = 41.199913024902344, lat = 3.0999999046325684, lon = -12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07015809416770935, sza = 41.849483489990234, lat = 3.0999999046325684, lon = -10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06976904968420665, sza = 42.44996643066406, lat = 3.0999999046325684, lon = -7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06927826503912608, sza = 42.995849609375, lat = 3.0999999046325684, lon = -5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06934104859828949, sza = 43.47991943359375, lat = 3.0999999046325684, lon = -2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06858443220456441, sza = 43.89385223388672, lat = 3.0999999046325684, lon = 0.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06847791870435078, sza = 44.22872543334961, lat = 3.0999999046325684, lon = 2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06849782665570577, sza = 44.475399017333984, lat = 3.0999999046325684, lon = 5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0687010685602824, sza = 44.62479019165039, lat = 3.0999999046325684, lon = 7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.10535443822542827, sza = 44.667938232421875, lat = 3.0999999046325684, lon = 10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13343467315038046, sza = 44.595951080322266, lat = 3.0999999046325684, lon = 12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12379318475723267, sza = 44.399845123291016, lat = 3.0999999046325684, lon = 15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11565377314885457, sza = 44.07016372680664, lat = 3.0999999046325684, lon = 17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1231808066368103, sza = 43.596431732177734, lat = 3.0999999046325684, lon = 20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1232226590315501, sza = 42.96631622314453, lat = 3.0999999046325684, lon = 22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12439193328221639, sza = 42.16455078125, lat = 3.0999999046325684, lon = 25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12888147433598837, sza = 41.17144012451172, lat = 3.0999999046325684, lon = 27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13043713569641113, sza = 40.73384094238281, lat = 3.0999999046325684, lon = 30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13178712129592896, sza = 41.2041015625, lat = 3.0999999046325684, lon = 32.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.18587825695673624, sza = 41.801177978515625, lat = 3.0999999046325684, lon = 35.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1784048080444336, sza = 42.36759948730469, lat = 3.0999999046325684, lon = 37.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1796446442604065, sza = 42.89625930786133, lat = 3.0999999046325684, lon = 40.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.17326470216115317, sza = 43.37824630737305, lat = 3.0999999046325684, lon = 42.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.18993103504180908, sza = 43.80335235595703, lat = 3.0999999046325684, lon = 45.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07307776808738708, sza = 44.160545349121094, lat = 3.0999999046325684, lon = 47.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07521576682726543, sza = 44.438297271728516, lat = 3.0999999046325684, lon = 50.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07133541504542033, sza = 45.41659927368164, lat = 5.0, lon = -30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0707532564798991, sza = 45.05755615234375, lat = 5.0, lon = -27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07128612200419109, sza = 44.55931854248047, lat = 5.0, lon = -25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07126551866531372, sza = 43.91120529174805, lat = 5.0, lon = -22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07062303026517232, sza = 43.09988784790039, lat = 5.0, lon = -20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07007784148057301, sza = 42.10820388793945, lat = 5.0, lon = -17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06986688574155171, sza = 42.09127426147461, lat = 5.0, lon = -15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07005465030670166, sza = 42.40532302856445, lat = 5.0, lon = -12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07155282298723857, sza = 43.05450439453125, lat = 5.0, lon = -10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1490835746129354, sza = 43.64985275268555, lat = 5.0, lon = -7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.09696686267852783, sza = 44.18674850463867, lat = 5.0, lon = -5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11810970306396484, sza = 44.658966064453125, lat = 5.0, lon = -2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06983781854311626, sza = 45.05910110473633, lat = 5.0, lon = 0.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0687128057082494, sza = 45.37900924682617, lat = 5.0, lon = 2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.06839763124783833, sza = 45.61009216308594, lat = 5.0, lon = 5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13668030500411987, sza = 45.743507385253906, lat = 5.0, lon = 7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13828009366989136, sza = 45.77021408081055, lat = 5.0, lon = 10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12476472059885661, sza = 45.680904388427734, lat = 5.0, lon = 12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11211967468261719, sza = 45.465797424316406, lat = 5.0, lon = 15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11215150356292725, sza = 45.11423873901367, lat = 5.0, lon = 17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.10815767447153728, sza = 44.614097595214844, lat = 5.0, lon = 20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11370546619097392, sza = 43.95096969604492, lat = 5.0, lon = 22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11751705408096313, sza = 43.10704040527344, lat = 5.0, lon = 25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11680362621943156, sza = 42.05964660644531, lat = 5.0, lon = 27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11829128861427307, sza = 42.09127426147461, lat = 5.0, lon = 30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14074718952178955, sza = 42.4558219909668, lat = 5.0, lon = 32.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1444744070370992, sza = 43.04650115966797, lat = 5.0, lon = 35.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1442511280377706, sza = 43.60207748413086, lat = 5.0, lon = 37.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1462152103583018, sza = 44.11619567871094, lat = 5.0, lon = 40.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.22178296248118082, sza = 44.580810546875, lat = 5.0, lon = 42.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.2385477622350057, sza = 44.98654556274414, lat = 5.0, lon = 45.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.2539331515630086, sza = 45.32305145263672, lat = 5.0, lon = 47.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07607122759024303, sza = 45.57926559448242, lat = 5.0, lon = 50.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07085182269414265, sza = 46.515193939208984, lat = 6.900000095367432, lon = -30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07047456502914429, sza = 46.136695861816406, lat = 6.900000095367432, lon = -27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07043478886286418, sza = 45.614620208740234, lat = 6.900000095367432, lon = -25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07057638963063557, sza = 44.93651580810547, lat = 6.900000095367432, lon = -22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07086208462715149, sza = 44.08694076538086, lat = 6.900000095367432, lon = -20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07049566507339478, sza = 43.24134826660156, lat = 6.900000095367432, lon = -17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0701076090335846, sza = 43.468414306640625, lat = 6.900000095367432, lon = -15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07451193531354268, sza = 43.69218444824219, lat = 6.900000095367432, lon = -12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1407209833463033, sza = 44.27678680419922, lat = 6.900000095367432, lon = -10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1461377739906311, sza = 44.868282318115234, lat = 6.900000095367432, lon = -7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13622738917668661, sza = 45.39767074584961, lat = 6.900000095367432, lon = -5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14860957860946655, sza = 45.85950469970703, lat = 6.900000095367432, lon = -2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11577686667442322, sza = 46.24713897705078, lat = 6.900000095367432, lon = 0.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.15037989616394043, sza = 46.553035736083984, lat = 6.900000095367432, lon = 2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14911182721455893, sza = 46.76901626586914, lat = 6.900000095367432, lon = 5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1359577476978302, sza = 46.88640213012695, lat = 6.900000095367432, lon = 7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1262060602506002, sza = 46.896034240722656, lat = 6.900000095367432, lon = 10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.130376398563385, sza = 46.788150787353516, lat = 6.900000095367432, lon = 12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12602657079696655, sza = 46.55216979980469, lat = 6.900000095367432, lon = 15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11757799983024597, sza = 46.176239013671875, lat = 6.900000095367432, lon = 17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11162573099136353, sza = 45.646644592285156, lat = 6.900000095367432, lon = 20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11167371273040771, sza = 44.94694900512695, lat = 6.900000095367432, lon = 22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12003735701243083, sza = 44.056846618652344, lat = 6.900000095367432, lon = 25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12836894392967224, sza = 43.167396545410156, lat = 6.900000095367432, lon = 27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1419892112414042, sza = 43.46841812133789, lat = 6.900000095367432, lon = 30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13833731412887573, sza = 43.768531799316406, lat = 6.900000095367432, lon = 32.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12832971413930258, sza = 44.31006622314453, lat = 6.900000095367432, lon = 35.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.15683969855308533, sza = 44.855873107910156, lat = 6.900000095367432, lon = 37.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1696639060974121, sza = 45.35675811767578, lat = 6.900000095367432, lon = 40.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.21856689453125, sza = 45.80533218383789, lat = 6.900000095367432, lon = 42.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1903347373008728, sza = 46.19287109375, lat = 6.900000095367432, lon = 45.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.28126319249471027, sza = 46.50953674316406, lat = 6.900000095367432, lon = 47.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08049192031224568, sza = 46.74458312988281, lat = 6.900000095367432, lon = 50.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07149183750152588, sza = 47.631221771240234, lat = 8.800000190734863, lon = -30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07102348407109578, sza = 47.2310676574707, lat = 8.800000190734863, lon = -27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0706074337164561, sza = 46.682456970214844, lat = 8.800000190734863, lon = -25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07077431678771973, sza = 45.971214294433594, lat = 8.800000190734863, lon = -22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07099161545435588, sza = 45.079833984375, lat = 8.800000190734863, lon = -20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07116080323855083, sza = 44.64070510864258, lat = 8.800000190734863, lon = -17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07143154740333557, sza = 44.863861083984375, lat = 8.800000190734863, lon = -15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13123742739359537, sza = 45.08041763305664, lat = 8.800000190734863, lon = -12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1284822622934977, sza = 45.51435852050781, lat = 8.800000190734863, lon = -10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12470831473668416, sza = 46.10308837890625, lat = 8.800000190734863, lon = -7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13680716355641684, sza = 46.62620544433594, lat = 8.800000190734863, lon = -5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12932260831197104, sza = 47.07887268066406, lat = 8.800000190734863, lon = -2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14024577538172403, sza = 47.455047607421875, lat = 8.800000190734863, lon = 0.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13661766052246094, sza = 47.747684478759766, lat = 8.800000190734863, lon = 2.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14601165056228638, sza = 47.948909759521484, lat = 8.800000190734863, lon = 5.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1567012071609497, sza = 48.05013656616211, lat = 8.800000190734863, lon = 7.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.18645048141479492, sza = 48.0420036315918, lat = 8.800000190734863, lon = 10.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.17992613712946573, sza = 47.91429138183594, lat = 8.800000190734863, lon = 12.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.15834099054336548, sza = 47.655582427978516, lat = 8.800000190734863, lon = 15.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1587103803952535, sza = 47.25284957885742, lat = 8.800000190734863, lon = 17.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.12902558843294779, sza = 46.6907958984375, lat = 8.800000190734863, lon = 20.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13541998465855917, sza = 45.950950622558594, lat = 8.800000190734863, lon = 22.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14146935939788818, sza = 45.01052474975586, lat = 8.800000190734863, lon = 25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.18473605314890543, sza = 44.568599700927734, lat = 8.800000190734863, lon = 27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.15133305390675864, sza = 44.86386489868164, lat = 8.800000190734863, lon = 30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.14762091636657715, sza = 45.154903411865234, lat = 8.800000190734863, lon = 32.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1415232519308726, sza = 45.59005355834961, lat = 8.800000190734863, lon = 35.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.17021310329437256, sza = 46.126949310302734, lat = 8.800000190734863, lon = 37.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1630224883556366, sza = 46.61564254760742, lat = 8.800000190734863, lon = 40.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1737156311670939, sza = 47.049232482910156, lat = 8.800000190734863, lon = 42.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.27931976318359375, sza = 47.419471740722656, lat = 8.800000190734863, lon = 45.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.3313694993654887, sza = 47.716922760009766, lat = 8.800000190734863, lon = 47.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.2972744107246399, sza = 47.9310188293457, lat = 8.800000190734863, lon = 50.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07202983895937602, sza = 48.76152420043945, lat = 10.699999809265137, lon = -30.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07156213124593098, sza = 48.337520599365234, lat = 10.699999809265137, lon = -27.5, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.07104450464248657, sza = 47.75967788696289, lat = 10.699999809265137, lon = -25.0, season = 0
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# ...
# Stored 'lon' (float)
# Rs = 0.18509344259897867, sza = 49.49675750732422, lat = 37.29999923706055, lon = -5.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13558894395828247, sza = 49.87454605102539, lat = 37.29999923706055, lon = -2.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08673635125160217, sza = 50.19852066040039, lat = 37.29999923706055, lon = 0.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.0929069717725118, sza = 50.464256286621094, lat = 37.29999923706055, lon = 2.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.09334097305933635, sza = 50.666744232177734, lat = 37.29999923706055, lon = 5.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11030708750089009, sza = 50.80038833618164, lat = 37.29999923706055, lon = 7.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.16391098499298096, sza = 50.8590087890625, lat = 37.29999923706055, lon = 10.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08584280808766682, sza = 50.835723876953125, lat = 37.29999923706055, lon = 12.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.15724544723828635, sza = 50.72283172607422, lat = 37.29999923706055, lon = 15.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08568880955378215, sza = 50.51152801513672, lat = 37.29999923706055, lon = 17.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08603710929552714, sza = 50.19158935546875, lat = 37.29999923706055, lon = 20.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13093028465906778, sza = 49.75090026855469, lat = 37.29999923706055, lon = 22.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.09089784820874532, sza = 49.174903869628906, lat = 37.29999923706055, lon = 25.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.09603949387868245, sza = 48.445838928222656, lat = 37.29999923706055, lon = 27.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.21833491325378418, sza = 47.55065155029297, lat = 37.29999923706055, lon = 30.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.186990757783254, sza = 48.018924713134766, lat = 37.29999923706055, lon = 32.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.16976940631866455, sza = 48.504093170166016, lat = 37.29999923706055, lon = 35.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.23698431253433228, sza = 48.9592399597168, lat = 37.29999923706055, lon = 37.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.22709399461746216, sza = 49.380775451660156, lat = 37.29999923706055, lon = 40.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.23231657346089682, sza = 49.76424789428711, lat = 37.29999923706055, lon = 42.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.18428277969360352, sza = 50.10437774658203, lat = 37.29999923706055, lon = 45.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.2279107371966044, sza = 50.39511489868164, lat = 37.29999923706055, lon = 47.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.13856983184814453, sza = 50.6296501159668, lat = 37.29999923706055, lon = 50.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08499268690745036, sza = 51.89634704589844, lat = 39.20000076293945, lon = -30.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08721550305684407, sza = 51.678871154785156, lat = 39.20000076293945, lon = -27.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08516517281532288, sza = 51.36238479614258, lat = 39.20000076293945, lon = -25.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08539058764775594, sza = 50.937416076660156, lat = 39.20000076293945, lon = -22.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08442864815394084, sza = 50.392578125, lat = 39.20000076293945, lon = -20.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08353272080421448, sza = 49.71406936645508, lat = 39.20000076293945, lon = -17.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08423628409703572, sza = 48.898773193359375, lat = 39.20000076293945, lon = -15.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08526304364204407, sza = 49.40236282348633, lat = 39.20000076293945, lon = -12.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08742575844128926, sza = 49.90435791015625, lat = 39.20000076293945, lon = -10.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.17377195755640665, sza = 50.3624153137207, lat = 39.20000076293945, lon = -7.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.17269674936930338, sza = 50.774593353271484, lat = 39.20000076293945, lon = -5.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.224098801612854, sza = 51.1381950378418, lat = 39.20000076293945, lon = -2.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.11641593774159749, sza = 51.44981384277344, lat = 39.20000076293945, lon = 0.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.09004213412602742, sza = 51.70541000366211, lat = 39.20000076293945, lon = 2.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08854556083679199, sza = 51.90032958984375, lat = 39.20000076293945, lon = 5.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08879266182581584, sza = 52.029293060302734, lat = 39.20000076293945, lon = 7.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08913931250572205, sza = 52.086395263671875, lat = 39.20000076293945, lon = 10.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08784842491149902, sza = 52.06496810913086, lat = 39.20000076293945, lon = 12.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08626795808474223, sza = 51.957462310791016, lat = 39.20000076293945, lon = 15.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08708931008974712, sza = 51.755184173583984, lat = 39.20000076293945, lon = 17.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08710682392120361, sza = 51.44799041748047, lat = 39.20000076293945, lon = 20.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1399449904759725, sza = 51.023887634277344, lat = 39.20000076293945, lon = 22.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08713739116986592, sza = 50.46845245361328, lat = 39.20000076293945, lon = 25.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1593014399210612, sza = 49.76418685913086, lat = 39.20000076293945, lon = 27.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1734218200047811, sza = 48.898773193359375, lat = 39.20000076293945, lon = 30.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.24372416734695435, sza = 49.34849548339844, lat = 39.20000076293945, lon = 32.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.23402162392934164, sza = 49.81703186035156, lat = 39.20000076293945, lon = 35.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.23334701855977377, sza = 50.25604248046875, lat = 39.20000076293945, lon = 37.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.19312095642089844, sza = 50.66218566894531, lat = 39.20000076293945, lon = 40.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.19663419326146445, sza = 51.03135299682617, lat = 39.20000076293945, lon = 42.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.2080253760019938, sza = 51.35865783691406, lat = 39.20000076293945, lon = 45.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.1743429700533549, sza = 51.638484954833984, lat = 39.20000076293945, lon = 47.5, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31
# Stored 'Rs' (float)
# Stored 'sza' (float)
# Stored 'season' (int)
# Stored 'lat' (float)
# Stored 'lon' (float)
# Rs = 0.08545391758282979, sza = 51.86442947387695, lat = 39.20000076293945, lon = 50.0, season = 3
#  Compute clear-sky sw flux w/o aerososl
#  Compute sw fluxs with aerosol
# IMMAX =  31

# %% [raw]
# import numpy as np
# import papermill as pm
# import concurrent.futures
#
# # Path to the notebook you want to execute
# notebook_path = "my_run_rrtm_sw.ipynb"
#
# # Define a function to execute the notebook for a given combination of parameters
# def execute_notebook_parallel(season, ilat, ilon):
#     output_notebook_path = f"NAf_dust_notebook_lat{lat_sza[ilat]:.2f}_lon{lon_sza[ilon]:.2f}_seas{seas_name[season]}.ipynb"
#     pm.execute_notebook(
#         notebook_path,
#         output_notebook_path,
#         parameters=dict(
#             Rs=float(all_merra2_albedo_2023[season][ilat, ilon]),
#             sza=float(sza_weighted_all[season][ilat, ilon]),
#             season=float(season),
#             lat=float(lat_sza[ilat]),
#             lon=float(lon_sza[ilon])
#         )
#     )
#     print(f"Notebook executed successfully for season {seas_name[season]} with parameters Rs={all_merra2_albedo_2023[season][ilat,ilon]}, sza={sza_weighted_all[season][ilat,ilon]}, lat={lat_sza[ilat]}, and lon={lon_sza[ilon]}. Output saved as '{output_notebook_path}'.")
#
# # Create a ThreadPoolExecutor to run tasks in parallel
# with concurrent.futures.ThreadPoolExecutor() as executor:
#     # Submit tasks for each combination of parameters
#     futures = []
#     for season in seasons:
#         for ilat in range(len(lat_sza)):
#             for ilon in range(len(lon_sza)):
#                 futures.append(executor.submit(execute_notebook_parallel, season, ilat, ilon))
#
#     # Wait for all tasks to complete
#     for future in concurrent.futures.as_completed(futures):
#         # Retrieve any exceptions raised by the task
#         try:
#             future.result()
#         except Exception as e:
#             print(f"An error occurred: {e}")

# %% [markdown]
# ## Load DustCOMM North African bulk dust seasonal DAOD

# %%
#----------
# using DustCOMM 2021 papers b) https://dustcomm.atmos.ucla.edu/
# specifically https://dustcomm.atmos.ucla.edu/data/K21b/ dataset DustCOMM_source_region_DAOD_seas_bin_abs.nc
# assumes aspherical dust shape, PM20 dust
#----------

#bulk DAOD data
daod_Dustcomm_PM20_Dataset = Dataset('../../Dust_Optical_Properties/DustCOMM_source_region_DAOD_seas_PM20_abs.nc')
print(daod_Dustcomm_PM20_Dataset) #[season,source,diameter,lat,lon,bin]

lat_Dustcomm_PM20 = np.array(daod_Dustcomm_PM20_Dataset.variables['lat'][:])
lon_Dustcomm_PM20 = np.array(daod_Dustcomm_PM20_Dataset.variables['lon'][:])
mean_Daod_Dustcomm_20PM = np.array(daod_Dustcomm_PM20_Dataset.variables['Mean'][:])
#dustcomm_seas = np.array(daod_Dustcomm_PM20_Dataset.variables['season'][:])
dustcomm_Sources_PM20 = np.array(daod_Dustcomm_PM20_Dataset.variables['source'][:]) 

#Create seasonal North African DAOD as a function of lat and lon
NAf_Daod_Dustcomm_20PM = mean_Daod_Dustcomm_20PM[:,:,0,:] + mean_Daod_Dustcomm_20PM[:,:,1,:] + mean_Daod_Dustcomm_20PM[:,:,2,:]

DJF_NAf_Daod_Dustcomm_20PM = NAf_Daod_Dustcomm_20PM[:,:,0]
MAM_NAf_Daod_Dustcomm_20PM = NAf_Daod_Dustcomm_20PM[:,:,1]
JJA_NAf_Daod_Dustcomm_20PM = NAf_Daod_Dustcomm_20PM[:,:,2]
SON_NAf_Daod_Dustcomm_20PM = NAf_Daod_Dustcomm_20PM[:,:,3]
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): season(4), source(9), lat(96), lon(144)
#     variables(dimensions): float64 season(season), float64 source(source), float64 lat(lat), float64 lon(lon), float64 Median(lat, lon, source, season), float64 Mean(lat, lon, source, season), float64 Neg1sigma(lat, lon, source, season), float64 Pos1sigman(lat, lon, source, season), float64 Neg2sigma(lat, lon, source, season), float64 Pos2sigma(lat, lon, source, season)
#     groups:

# %% [markdown]
# ## Multiply: (SW DRE/column RRTM DAOD) * DustCOMM North African Dust DAOD
