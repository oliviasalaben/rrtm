# %%
import os
import matplotlib.pyplot as plt
import scipy.io as io
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
import sys
import math
from netCDF4 import Dataset
import os, calendar, sys, fnmatch, datetime
import scipy

# %% [markdown]
# ## Read in Yue coordinate matrix and Yue dust optical properties matrices

# %%
Qe_matrix = io.loadmat('Qe_matrix.mat')
Qe_matrix = Qe_matrix['array']

SSA_matrix = io.loadmat('SSA_matrix.mat')
SSA_matrix = SSA_matrix['array']

g_matrix = io.loadmat('g_matrix.mat')
g_matrix = g_matrix['array']

# %%
# coordinate matrix
Yue_coord_matrix = io.loadmat('coordinate_matrix_tuple.mat')
print(Yue_coord_matrix.keys())
Yue_coord_matrix = Yue_coord_matrix['array']
Yue_coord_matrix = Yue_coord_matrix[0]
print(Yue_coord_matrix[0][0])
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'array'])
# [3.30693964e-01 4.16674394e-01 4.18879020e-01 5.25142014e-01
#  5.27787566e-01 5.71198664e-01 6.62049315e-01 6.65179885e-01
#  7.19710317e-01 8.34340870e-01 8.38595799e-01 8.97597901e-01
#  9.07063479e-01 1.05160680e+00 1.05683177e+00 1.13097336e+00
#  1.14353973e+00 1.32542141e+00 1.33203529e+00 1.42538547e+00
#  1.44113423e+00 1.67033521e+00 1.67886711e+00 1.79699100e+00
#  1.81641175e+00 2.10519777e+00 2.11575793e+00 2.26463950e+00
#  2.28936425e+00 2.65315767e+00 2.66658384e+00 2.85436133e+00
#  2.88512445e+00 3.34397736e+00 3.36066638e+00 3.59757239e+00
#  3.63625070e+00 4.21436387e+00 4.23570466e+00 4.53376700e+00
#  4.58272688e+00 5.31127575e+00 5.33819424e+00 5.71410824e+00
#  5.77596089e+00 6.69390721e+00 6.72761595e+00 7.20142796e+00
#  7.27935578e+00 8.43666440e+00 8.47894913e+00 9.07650998e+00
#  9.17402175e+00 1.06328030e+01 1.06864416e+01 1.14389877e+01
#  1.15622034e+01 1.34007115e+01 1.34682171e+01 1.44163199e+01
#  1.45724203e+01 1.68895328e+01 1.69742345e+01 1.81691767e+01
#  1.83657507e+01 2.12861090e+01 2.13934082e+01 2.28995177e+01
#  2.31466835e+01 2.68272171e+01 2.69624048e+01 2.88604653e+01
#  2.91728294e+01 3.38111429e+01 3.39811417e+01 3.63733597e+01
#  3.67669156e+01 4.26128934e+01 4.28274477e+01 4.58430176e+01
#  4.63379204e+01 5.37060225e+01 5.39763317e+01 5.77765817e+01
#  5.84010650e+01 6.77922625e+01 6.80276284e+01 7.28167321e+01
#  7.36040887e+01 8.09985260e+01 8.58701992e+01 9.17731022e+01
#  9.27649479e+01 9.67772577e+01 1.02598133e+02 1.15629459e+02
#  1.15663568e+02 1.17095726e+02 1.22584526e+02 1.38154679e+02
#  1.39906545e+02 1.45773490e+02 1.46463982e+02 1.65067545e+02
#  1.67160718e+02 1.74995926e+02 1.84007570e+02 1.97222904e+02
#  1.99723611e+02 2.09085557e+02 2.19853142e+02 2.38630808e+02
#  2.49815678e+02 2.62681128e+02 2.85116669e+02 3.13851389e+02
#  3.40657743e+02 3.74991270e+02 4.48040480e+02 5.35319310e+02]

# %%
print(Qe_matrix.shape)
print(SSA_matrix.shape)
print(g_matrix.shape)
print(Yue_coord_matrix.shape)
# Out:
# (120, 4, 4)
# (120, 4, 4)
# (120, 4, 4)
# (3,)

# %%
tuple1 = Yue_coord_matrix[0][0]
tuple2 = Yue_coord_matrix[1][0]
tuple3 = Yue_coord_matrix[2][0]
tuple_array = (tuple1, tuple2, tuple3)
print(tuple_array)
# Out:
# (array([3.30693964e-01, 4.16674394e-01, 4.18879020e-01, 5.25142014e-01,
#        5.27787566e-01, 5.71198664e-01, 6.62049315e-01, 6.65179885e-01,
#        7.19710317e-01, 8.34340870e-01, 8.38595799e-01, 8.97597901e-01,
#        9.07063479e-01, 1.05160680e+00, 1.05683177e+00, 1.13097336e+00,
#        1.14353973e+00, 1.32542141e+00, 1.33203529e+00, 1.42538547e+00,
#        1.44113423e+00, 1.67033521e+00, 1.67886711e+00, 1.79699100e+00,
#        1.81641175e+00, 2.10519777e+00, 2.11575793e+00, 2.26463950e+00,
#        2.28936425e+00, 2.65315767e+00, 2.66658384e+00, 2.85436133e+00,
#        2.88512445e+00, 3.34397736e+00, 3.36066638e+00, 3.59757239e+00,
#        3.63625070e+00, 4.21436387e+00, 4.23570466e+00, 4.53376700e+00,
#        4.58272688e+00, 5.31127575e+00, 5.33819424e+00, 5.71410824e+00,
#        5.77596089e+00, 6.69390721e+00, 6.72761595e+00, 7.20142796e+00,
#        7.27935578e+00, 8.43666440e+00, 8.47894913e+00, 9.07650998e+00,
#        9.17402175e+00, 1.06328030e+01, 1.06864416e+01, 1.14389877e+01,
#        1.15622034e+01, 1.34007115e+01, 1.34682171e+01, 1.44163199e+01,
#        1.45724203e+01, 1.68895328e+01, 1.69742345e+01, 1.81691767e+01,
#        1.83657507e+01, 2.12861090e+01, 2.13934082e+01, 2.28995177e+01,
#        2.31466835e+01, 2.68272171e+01, 2.69624048e+01, 2.88604653e+01,
#        2.91728294e+01, 3.38111429e+01, 3.39811417e+01, 3.63733597e+01,
#        3.67669156e+01, 4.26128934e+01, 4.28274477e+01, 4.58430176e+01,
#        4.63379204e+01, 5.37060225e+01, 5.39763317e+01, 5.77765817e+01,
#        5.84010650e+01, 6.77922625e+01, 6.80276284e+01, 7.28167321e+01,
#        7.36040887e+01, 8.09985260e+01, 8.58701992e+01, 9.17731022e+01,
#        9.27649479e+01, 9.67772577e+01, 1.02598133e+02, 1.15629459e+02,
#        1.15663568e+02, 1.17095726e+02, 1.22584526e+02, 1.38154679e+02,
#        1.39906545e+02, 1.45773490e+02, 1.46463982e+02, 1.65067545e+02,
#        1.67160718e+02, 1.74995926e+02, 1.84007570e+02, 1.97222904e+02,
#        1.99723611e+02, 2.09085557e+02, 2.19853142e+02, 2.38630808e+02,
#        2.49815678e+02, 2.62681128e+02, 2.85116669e+02, 3.13851389e+02,
#        3.40657743e+02, 3.74991270e+02, 4.48040480e+02, 5.35319310e+02]), array([1.5 , 1.52, 1.53, 1.56]), array([0.0005, 0.001 , 0.002 , 0.003 ]))

# %%
print(Qe_matrix[0])
# Out:
# [[0.00579967 0.00632022 0.00770392 0.0086648 ]
#  [0.01248496 0.01330467 0.01139741 0.01176294]
#  [0.01326303 0.01411491 0.01287314 0.01318581]
#  [0.0149366  0.01585537 0.01647204 0.01705219]]

# %%
print(type(Yue_coord_matrix))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Use these matrices to interpolate the values of Qext, SSA, and g and compare the results against Figure 2 in Huang et al. (2023)? The results plotted there were obtained for n =1.53 and k = 10^(-2.75) (except for panel c). If they agree we know the procedure was successful.

# %%
n =1.53
print(type(n))
k = 10**(-2.750)
print(type(k))
#wavelength_550 = float(550*(10**-3)) #500nm *10^-3 = um
wavelength_10um = float(10) #10 um = 10 * 10^3 nm
print(type(wavelength_10um))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# Define the Yue dust diamater range arrays
diameter_range_1 = np.logspace(np.log(0.1), np.log(20), 230) #in um
diameter_range_2 = np.logspace(np.log(20.5), np.log(70), 70) #in um

# Concatenate the arrays
diameter_range = np.concatenate((diameter_range_1, diameter_range_2))
print(len(diameter_range))
# Out:
# 300

# %%
print(Qe_matrix.shape, Qe_matrix)
# Out:
# (120, 4, 4) [[[0.00579967 0.00632022 0.00770392 0.0086648 ]
#   [0.01248496 0.01330467 0.01139741 0.01176294]
#   [0.01326303 0.01411491 0.01287314 0.01318581]
#   [0.0149366  0.01585537 0.01647204 0.01705219]]
#
#  [[0.01340117 0.014065   0.01592071 0.01716373]
#   [0.02430584 0.02540136 0.02369377 0.02403838]
#   [0.02728247 0.02849257 0.02702707 0.02725993]
#   [0.03362425 0.03507405 0.03559898 0.03619906]]
#
#  [[0.0135232  0.01418854 0.01615054 0.01741957]
#   [0.02362136 0.0246824  0.02380374 0.02430806]
#   [0.02674221 0.02792281 0.02715652 0.0275623 ]
#   [0.03367749 0.03512014 0.03594494 0.03667028]]
#
#  ...
#
#  [[       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]]
#
#  [[       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]]
#
#  [[       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]]]

# %% [markdown]
# # 550 nm wavelength Qe plots

# %%
# Check if size_parameter is within the range of tuple_array
min_size = Yue_coord_matrix[0][0][0]
max_size = Yue_coord_matrix[0][0][-1]

# %%
Qe_interp_matrix = [] #np.zeros(120, dtype=object)
Qe_interp_only = []
plot_range = []
for i in range(len(diameter_range)):
    size_parameter = np.pi * diameter_range[i] / wavelength_10um
    #print(size_parameter)

    if size_parameter < min_size or size_parameter > max_size:
        print("size_parameter is out of range: " +str(size_parameter))
    else:
        #print("size_parameter is within the range.")
        point = np.array([size_parameter, n, k])
        #Qe_interp = scipy.interpolate.interpn(Yue_coord_matrix, Qe_matrix, point)
        plot_range.append(size_parameter  * wavelength_10um / np.pi)
        Qe_interp = scipy.interpolate.interpn(tuple_array, Qe_matrix,[size_parameter, n, k])
        Qe_interp_only.append(Qe_interp[0])
        Qe_interp_matrix.append([size_parameter,n,k,Qe_interp[0]])
# Out:
# size_parameter is out of range: 0.0015651817655340007
# size_parameter is out of range: 0.0016508268989609443
# size_parameter is out of range: 0.0017411584458391818
# size_parameter is out of range: 3850.011483094671
# size_parameter is out of range: 4011.069119983188
# size_parameter is out of range: 4178.864285451558
# size_parameter is out of range: 4353.6788307192655
# size_parameter is out of range: 4535.806397695659
# size_parameter is out of range: 4725.5529122202115
# size_parameter is out of range: 4923.237097936475
# size_parameter is out of range: 5129.191011663031
# size_parameter is out of range: 5343.7606011605385
# size_parameter is out of range: 5567.306286231866

# %%
plt.plot(plot_range,Qe_interp_only)
plt.ylabel('Qe')
plt.xlabel('Dust Geometric Diameter')
plt.xscale('log')
plt.xlim(0.2,70)
plt.title('Qe at 10 um for ellipsoidal dust')

# Customize x-axis ticks and labels
plt.xticks([0.2, 1, 10, 70], ['0.2', '1', '10', '70'])  # Adjust these values according to your data
plt.show()

# %% [markdown]
# # SSA interpolation

# %%
SSA_interp_matrix_k1 = [] #np.zeros(120, dtype=object)
SSA_interp_matrix_k2 = [] #np.zeros(120, dtype=object)
SSA_interp_matrix_k3 = [] #np.zeros(120, dtype=object)
SSA_interp_only_k1 = []
SSA_interp_only_k2 = []
SSA_interp_only_k3 = []
k_SSA = [0.0005, 0.001, 0.003]
plot_range = []
for i in range(len(diameter_range)):
    size_parameter = np.pi * diameter_range[i] / wavelength_10um
    #print(size_parameter)

    if size_parameter < min_size or size_parameter > max_size:
        print("size_parameter is out of range: " +str(size_parameter))
    else:
        #print("size_parameter is within the range.")
        point = np.array([size_parameter, n, k_SSA])
        #Qe_interp = scipy.interpolate.interpn(Yue_coord_matrix, Qe_matrix, point)
        plot_range.append(size_parameter  * wavelength_10um / np.pi)
        for ks in range(len(k_SSA)):
            if ks == 0: 
                SSA_interp = scipy.interpolate.interpn(tuple_array, SSA_matrix,[size_parameter, n, k_SSA[ks]])
                SSA_interp_only_k1.append(SSA_interp[0])
                SSA_interp_matrix_k1.append([size_parameter,n,k_SSA[ks],SSA_interp[0]])
            if ks == 1:
                SSA_interp = scipy.interpolate.interpn(tuple_array, SSA_matrix,[size_parameter, n, k_SSA[ks]])
                SSA_interp_only_k2.append(SSA_interp[0])
                SSA_interp_matrix_k2.append([size_parameter,n,k_SSA[ks],SSA_interp[0]])
            if ks == 2:
                SSA_interp = scipy.interpolate.interpn(tuple_array, SSA_matrix,[size_parameter, n, k_SSA[ks]])
                SSA_interp_only_k3.append(SSA_interp[0])
                SSA_interp_matrix_k3.append([size_parameter,n,k_SSA[ks],SSA_interp[0]])
# Out:
# size_parameter is out of range: 0.0015651817655340007
# size_parameter is out of range: 0.0016508268989609443
# size_parameter is out of range: 0.0017411584458391818
# size_parameter is out of range: 0.0018364328418838311
# size_parameter is out of range: 0.0019369205547080995
# size_parameter is out of range: 0.0020429068516343023
# size_parameter is out of range: 0.0021546926095186865
# size_parameter is out of range: 0.0022725951688890482
# size_parameter is out of range: 0.0023969492348198673
# size_parameter is out of range: 0.0025281078271024186
# size_parameter is out of range: 0.0026664432824071993
# size_parameter is out of range: 0.002812348311283659
# size_parameter is out of range: 0.00296623711299785
# size_parameter is out of range: 0.003128546551372874
VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   point = np.array([size_parameter, n, k_SSA])

# %%
plt.plot(plot_range,SSA_interp_only_k1, label='k=0.0005')
plt.plot(plot_range,SSA_interp_only_k2, label='k=0.001')
plt.plot(plot_range,SSA_interp_only_k3, label='k=0.003')
plt.ylabel('SSA')
plt.xlabel('Dust Geometric Diameter')
plt.xscale('log')
plt.xlim(0.2,70)
plt.title('SSA at 10 um for ellipsoidal dust')
#plt.legend(['k=0.0005', 'k=0.001', 'k=0.003'])
plt.legend()
# Customize x-axis ticks and labels
plt.xticks([0.2, 1, 10, 70], ['0.2', '1', '10', '70'])  # Adjust these values according to your data
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb7935b4c0>,
#   <matplotlib.axis.XTick at 0x7fcb7935b490>,
#   <matplotlib.axis.XTick at 0x7fcb7935b070>,
#   <matplotlib.axis.XTick at 0x7fcb5b5caa00>],
#  [Text(0.2, 0, '0.2'),
#   Text(1.0, 0, '1'),
#   Text(10.0, 0, '10'),
#   Text(70.0, 0, '70')])

# %% [markdown]
# # g interpolation

# %%
g_interp_matrix = [] #np.zeros(120, dtype=object)
g_interp_only = []
plot_range = []
for i in range(len(diameter_range)):
    size_parameter = np.pi * diameter_range[i] / wavelength_10um
    #print(size_parameter)

    if size_parameter < min_size or size_parameter > max_size:
        print("size_parameter is out of range: " +str(size_parameter))
    else:
        #print("size_parameter is within the range.")
        point = np.array([size_parameter, n, k])
        #Qe_interp = scipy.interpolate.interpn(Yue_coord_matrix, Qe_matrix, point)
        plot_range.append(size_parameter  * wavelength_10um / np.pi)
        g_interp = scipy.interpolate.interpn(tuple_array, g_matrix,[size_parameter, n, k])
        g_interp_only.append(g_interp[0])
        g_interp_matrix.append([size_parameter,n,k,g_interp[0]])
# Out:
# size_parameter is out of range: 0.0015651817655340007
# size_parameter is out of range: 0.0016508268989609443
# size_parameter is out of range: 0.0017411584458391818
# size_parameter is out of range: 0.0018364328418838311
# size_parameter is out of range: 0.0019369205547080995
# size_parameter is out of range: 0.0020429068516343023
# size_parameter is out of range: 0.0021546926095186865
# size_parameter is out of range: 0.0022725951688890482
# size_parameter is out of range: 0.0023969492348198673
# size_parameter is out of range: 0.0025281078271024186
# size_parameter is out of range: 0.0026664432824071993
# size_parameter is out of range: 0.002812348311283659
# size_parameter is out of range: 0.00296623711299785
# size_parameter is out of range: 0.003128546551372874
# size_parameter is out of range: 0.0032997373949700828
# size_parameter is out of range: 0.003480295625131723
# size_parameter is out of range: 0.003670733815598326
# size_parameter is out of range: 0.0038715925876173403
# size_parameter is out of range: 0.004083442144673818
# size_parameter is out of range: 0.0043068838911999655
# size_parameter is out of range: 0.004542552139858824
# size_parameter is out of range: 0.004791115912248751
# size_parameter is out of range: 0.0050532808381406015
# size_parameter is out of range: 0.005329791158639203
# size_parameter is out of range: 0.005621431838955756
# size_parameter is out of range: 0.005929030796788989
# size_parameter is out of range: 0.0062534612526409985
# size_parameter is out of range: 0.00659564420873999
# size_parameter is out of range: 0.006956551063607076
# size_parameter is out of range: 560.9838170356675
# size_parameter is out of range: 584.4514685741617
# size_parameter is out of range: 608.9008430287322
# size_parameter is out of range: 634.3730088412892
# size_parameter is out of range: 660.9107524710071
# size_parameter is out of range: 688.5586502641931
# size_parameter is out of range: 717.3631433306807
# size_parameter is out of range: 747.3726155525379
# size_parameter is out of range: 778.6374748561082
# size_parameter is out of range: 811.2102378839121
# size_parameter is out of range: 845.1456182086324
# size_parameter is out of range: 880.5006182373479
# size_parameter is out of range: 917.3346249604134
# size_parameter is out of range: 955.7095097057911
# size_parameter is out of range: 995.6897320664206
# size_parameter is out of range: 1037.3424481751729
# size_parameter is out of range: 1080.737623509287
# size_parameter is out of range: 1125.9481504137434
# size_parameter is out of range: 1173.0499705410105
# size_parameter is out of range: 1222.1222024128026
# size_parameter is out of range: 1273.2472743181415
# size_parameter is out of range: 1326.5110627709469
# size_parameter is out of range: 1382.0030367597205
# size_parameter is out of range: 1439.8164080316333
# size_parameter is out of range: 1500.0482876634546
# size_parameter is out of range: 1562.7998491823187
# size_parameter is out of range: 1628.1764985103136
# size_parameter is out of range: 1696.2880510183895
# size_parameter is out of range: 1767.2489159869401
# size_parameter is out of range: 1841.1782887829584
# size_parameter is out of range: 1918.200351076517
# size_parameter is out of range: 1998.4444794329288
# size_parameter is out of range: 2082.0454626309456
# size_parameter is out of range: 2169.143728072031
# size_parameter is out of range: 2259.8855776610153
# size_parameter is out of range: 2354.4234335543597
# size_parameter is out of range: 2452.9160941888213
# size_parameter is out of range: 2555.5290010205454
# size_parameter is out of range: 2662.4345164227007
# size_parameter is out of range: 2773.8122132083695
# size_parameter is out of range: 2889.8491762651033
# size_parameter is out of range: 3010.7403168077226
# size_parameter is out of range: 3136.6886997772895
# size_parameter is out of range: 3267.9058849361686
# size_parameter is out of range: 3404.612282232122
# size_parameter is out of range: 3547.0375220283336
# size_parameter is out of range: 3695.420840821343
# size_parameter is out of range: 3850.011483094671
# size_parameter is out of range: 4011.069119983188
# size_parameter is out of range: 4178.864285451558
# size_parameter is out of range: 4353.6788307192655
# size_parameter is out of range: 4535.806397695659
# size_parameter is out of range: 4725.5529122202115
# size_parameter is out of range: 4923.237097936475
# size_parameter is out of range: 5129.191011663031
# size_parameter is out of range: 5343.7606011605385
# size_parameter is out of range: 5567.306286231866

# %%
plt.plot(plot_range,g_interp_only)
plt.ylabel('g')
plt.xlabel('Dust Geometric Diameter')
plt.xscale('log')
plt.xlim(0.2,70)
plt.title('g at 10 um for ellipsoidal dust')
# Customize x-axis ticks and labels
plt.xticks([0.2, 1, 10, 70], ['0.2', '1', '10', '70'])  # Adjust these values according to your data
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb48880730>,
#   <matplotlib.axis.XTick at 0x7fcb48880700>,
#   <matplotlib.axis.XTick at 0x7fcb488802e0>,
#   <matplotlib.axis.XTick at 0x7fcb79093040>],
#  [Text(0.2, 0, '0.2'),
#   Text(1.0, 0, '1'),
#   Text(10.0, 0, '10'),
#   Text(70.0, 0, '70')])
