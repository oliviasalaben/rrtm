# %%
import os
import matplotlib.pyplot as plt
import scipy.io as io
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
import sys
import math
from netCDF4 import Dataset
import os, calendar, sys, fnmatch, datetime
import scipy

# %% [markdown]
# ## Read in Yue coordinate matrix and Yue dust optical properties matrices

# %%
Qe_matrix = io.loadmat('Qe_matrix.mat')
Qe_matrix = Qe_matrix['array']

SSA_matrix = io.loadmat('SSA_matrix.mat')
SSA_matrix = SSA_matrix['array']

g_matrix = io.loadmat('g_matrix.mat')
g_matrix = g_matrix['array']

# %%
# coordinate matrix
Yue_coord_matrix = io.loadmat('coordinate_matrix_tuple.mat')
Yue_coord_matrix = Yue_coord_matrix['array']
Yue_coord_matrix = Yue_coord_matrix[0]
print(Yue_coord_matrix[0][0])
# Out:
# [3.30693964e-01 4.16674394e-01 4.18879020e-01 5.25142014e-01
#  5.27787566e-01 5.71198664e-01 6.62049315e-01 6.65179885e-01
#  7.19710317e-01 8.34340870e-01 8.38595799e-01 8.97597901e-01
#  9.07063479e-01 1.05160680e+00 1.05683177e+00 1.13097336e+00
#  1.14353973e+00 1.32542141e+00 1.33203529e+00 1.42538547e+00
#  1.44113423e+00 1.67033521e+00 1.67886711e+00 1.79699100e+00
#  1.81641175e+00 2.10519777e+00 2.11575793e+00 2.26463950e+00
#  2.28936425e+00 2.65315767e+00 2.66658384e+00 2.85436133e+00
#  2.88512445e+00 3.34397736e+00 3.36066638e+00 3.59757239e+00
#  3.63625070e+00 4.21436387e+00 4.23570466e+00 4.53376700e+00
#  4.58272688e+00 5.31127575e+00 5.33819424e+00 5.71410824e+00
#  5.77596089e+00 6.69390721e+00 6.72761595e+00 7.20142796e+00
#  7.27935578e+00 8.43666440e+00 8.47894913e+00 9.07650998e+00
#  9.17402175e+00 1.06328030e+01 1.06864416e+01 1.14389877e+01
#  1.15622034e+01 1.34007115e+01 1.34682171e+01 1.44163199e+01
#  1.45724203e+01 1.68895328e+01 1.69742345e+01 1.81691767e+01
#  1.83657507e+01 2.12861090e+01 2.13934082e+01 2.28995177e+01
#  2.31466835e+01 2.68272171e+01 2.69624048e+01 2.88604653e+01
#  2.91728294e+01 3.38111429e+01 3.39811417e+01 3.63733597e+01
#  3.67669156e+01 4.26128934e+01 4.28274477e+01 4.58430176e+01
#  4.63379204e+01 5.37060225e+01 5.39763317e+01 5.77765817e+01
#  5.84010650e+01 6.77922625e+01 6.80276284e+01 7.28167321e+01
#  7.36040887e+01 8.09985260e+01 8.58701992e+01 9.17731022e+01
#  9.27649479e+01 9.67772577e+01 1.02598133e+02 1.15629459e+02
#  1.15663568e+02 1.17095726e+02 1.22584526e+02 1.38154679e+02
#  1.39906545e+02 1.45773490e+02 1.46463982e+02 1.65067545e+02
#  1.67160718e+02 1.74995926e+02 1.84007570e+02 1.97222904e+02
#  1.99723611e+02 2.09085557e+02 2.19853142e+02 2.38630808e+02
#  2.49815678e+02 2.62681128e+02 2.85116669e+02 3.13851389e+02
#  3.40657743e+02 3.74991270e+02 4.48040480e+02 5.35319310e+02]

# %%
print(Qe_matrix.shape)
print(SSA_matrix.shape)
print(g_matrix.shape)
print(Yue_coord_matrix.shape)
# Out:
# (120, 4, 4)
# (120, 4, 4)
# (120, 4, 4)
# (3,)

# %%
tuple1 = Yue_coord_matrix[0][0]
tuple2 = Yue_coord_matrix[1][0]
tuple3 = Yue_coord_matrix[2][0]
tuple_array = (tuple1, tuple2, tuple3)
print(tuple_array)
# Out:
# (array([3.30693964e-01, 4.16674394e-01, 4.18879020e-01, 5.25142014e-01,
#        5.27787566e-01, 5.71198664e-01, 6.62049315e-01, 6.65179885e-01,
#        7.19710317e-01, 8.34340870e-01, 8.38595799e-01, 8.97597901e-01,
#        9.07063479e-01, 1.05160680e+00, 1.05683177e+00, 1.13097336e+00,
#        1.14353973e+00, 1.32542141e+00, 1.33203529e+00, 1.42538547e+00,
#        1.44113423e+00, 1.67033521e+00, 1.67886711e+00, 1.79699100e+00,
#        1.81641175e+00, 2.10519777e+00, 2.11575793e+00, 2.26463950e+00,
#        2.28936425e+00, 2.65315767e+00, 2.66658384e+00, 2.85436133e+00,
#        2.88512445e+00, 3.34397736e+00, 3.36066638e+00, 3.59757239e+00,
#        3.63625070e+00, 4.21436387e+00, 4.23570466e+00, 4.53376700e+00,
#        4.58272688e+00, 5.31127575e+00, 5.33819424e+00, 5.71410824e+00,
#        5.77596089e+00, 6.69390721e+00, 6.72761595e+00, 7.20142796e+00,
#        7.27935578e+00, 8.43666440e+00, 8.47894913e+00, 9.07650998e+00,
#        9.17402175e+00, 1.06328030e+01, 1.06864416e+01, 1.14389877e+01,
#        1.15622034e+01, 1.34007115e+01, 1.34682171e+01, 1.44163199e+01,
#        1.45724203e+01, 1.68895328e+01, 1.69742345e+01, 1.81691767e+01,
#        1.83657507e+01, 2.12861090e+01, 2.13934082e+01, 2.28995177e+01,
#        2.31466835e+01, 2.68272171e+01, 2.69624048e+01, 2.88604653e+01,
#        2.91728294e+01, 3.38111429e+01, 3.39811417e+01, 3.63733597e+01,
#        3.67669156e+01, 4.26128934e+01, 4.28274477e+01, 4.58430176e+01,
#        4.63379204e+01, 5.37060225e+01, 5.39763317e+01, 5.77765817e+01,
#        5.84010650e+01, 6.77922625e+01, 6.80276284e+01, 7.28167321e+01,
#        7.36040887e+01, 8.09985260e+01, 8.58701992e+01, 9.17731022e+01,
#        9.27649479e+01, 9.67772577e+01, 1.02598133e+02, 1.15629459e+02,
#        1.15663568e+02, 1.17095726e+02, 1.22584526e+02, 1.38154679e+02,
#        1.39906545e+02, 1.45773490e+02, 1.46463982e+02, 1.65067545e+02,
#        1.67160718e+02, 1.74995926e+02, 1.84007570e+02, 1.97222904e+02,
#        1.99723611e+02, 2.09085557e+02, 2.19853142e+02, 2.38630808e+02,
#        2.49815678e+02, 2.62681128e+02, 2.85116669e+02, 3.13851389e+02,
#        3.40657743e+02, 3.74991270e+02, 4.48040480e+02, 5.35319310e+02]), array([1.5 , 1.52, 1.53, 1.56]), array([0.0005, 0.001 , 0.002 , 0.003 ]))

# %%
print(Qe_matrix[0])
# Out:
# [[0.00579967 0.00632022 0.00770392 0.0086648 ]
#  [0.01248496 0.01330467 0.01139741 0.01176294]
#  [0.01326303 0.01411491 0.01287314 0.01318581]
#  [0.0149366  0.01585537 0.01647204 0.01705219]]

# %%
print(type(Yue_coord_matrix))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Use these matrices to interpolate the values of Qext, SSA, and g and compare the results against Figure 2 in Huang et al. (2023)? The results plotted there were obtained for n =1.53 and k = 10^(-2.75) (except for panel c). If they agree we know the procedure was successful.

# %%
n =1.53
print(type(n))
k = 10**(-2.750)
print(type(k))
wavelength_550 = float(550*(10**-3)) #500nm *10^-3 = um
wavelength_10um = float(10) #10 um = 10 * 10^3 nm
print(type(wavelength_550))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# Define the Yue dust diamater range arrays
diameter_range_1 = np.logspace(np.log(0.1), np.log(20), 230) #in um
diameter_range_2 = np.logspace(np.log(20.5), np.log(70), 70) #in um

# Concatenate the arrays
diameter_range = np.concatenate((diameter_range_1, diameter_range_2))
print(len(diameter_range))
# Out:
# 300

# %%
print(Qe_matrix.shape, Qe_matrix)
# Out:
# (120, 4, 4) [[[0.00579967 0.00632022 0.00770392 0.0086648 ]
#   [0.01248496 0.01330467 0.01139741 0.01176294]
#   [0.01326303 0.01411491 0.01287314 0.01318581]
#   [0.0149366  0.01585537 0.01647204 0.01705219]]
#
#  [[0.01340117 0.014065   0.01592071 0.01716373]
#   [0.02430584 0.02540136 0.02369377 0.02403838]
#   [0.02728247 0.02849257 0.02702707 0.02725993]
#   [0.03362425 0.03507405 0.03559898 0.03619906]]
#
#  [[0.0135232  0.01418854 0.01615054 0.01741957]
#   [0.02362136 0.0246824  0.02380374 0.02430806]
#   [0.02674221 0.02792281 0.02715652 0.0275623 ]
#   [0.03367749 0.03512014 0.03594494 0.03667028]]
#
#  ...
#
#  [[       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]]
#
#  [[       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]]
#
#  [[       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]
#   [       nan        nan        nan        nan]]]

# %% [markdown]
# # 550 nm wavelength Qe plots

# %%
# Check if size_parameter is within the range of tuple_array
min_size = Yue_coord_matrix[0][0][0]
max_size = Yue_coord_matrix[0][0][-1]

# %%
Qe_interp_matrix = [] #np.zeros(120, dtype=object)
Qe_interp_only = []
plot_range = []
for i in range(len(diameter_range)):
    size_parameter = np.pi * diameter_range[i] / wavelength_550
    #print(size_parameter)

    if size_parameter < min_size or size_parameter > max_size:
        print("size_parameter is out of range: " +str(size_parameter))
    else:
        #print("size_parameter is within the range.")
        point = np.array([size_parameter, n, k])
        #Qe_interp = scipy.interpolate.interpn(Yue_coord_matrix, Qe_matrix, point)
        plot_range.append(size_parameter  * wavelength_550 / np.pi)
        Qe_interp = scipy.interpolate.interpn(tuple_array, Qe_matrix,[size_parameter, n, k])
        Qe_interp_only.append(Qe_interp[0])
        Qe_interp_matrix.append([size_parameter,n,k,Qe_interp[0]])
# Out:
# size_parameter is out of range: 0.028457850282436373
# size_parameter is out of range: 0.03001503452656262
# size_parameter is out of range: 0.031657426287985124
# size_parameter is out of range: 0.03338968803425147
# size_parameter is out of range: 0.03521673735832908
# size_parameter is out of range: 0.03714376093880549
# size_parameter is out of range: 0.03917622926397612
# size_parameter is out of range: 0.04131991216161906
# size_parameter is out of range: 0.043580895178543036
# size_parameter is out of range: 0.0459655968564076
# size_parameter is out of range: 0.048480786952858165
# size_parameter is out of range: 0.05113360565970289
# size_parameter is out of range: 0.05393158387268817
# size_parameter is out of range: 0.05688266457041588
# size_parameter is out of range: 0.05999522536309241
# size_parameter is out of range: 0.06327810227512222
# size_parameter is out of range: 0.06674061482906046
# size_parameter is out of range: 0.07039259250213345
# size_parameter is out of range: 0.07424440263043304
# size_parameter is out of range: 0.07830697983999936
# size_parameter is out of range: 0.08259185708834225
# size_parameter is out of range: 0.08711119840452274
# size_parameter is out of range: 0.0918778334207382
# size_parameter is out of range: 0.09690529379344004
# size_parameter is out of range: 0.10220785161737737
# size_parameter is out of range: 0.10780055994161797
# size_parameter is out of range: 0.11369929550256361
# size_parameter is out of range: 0.11992080379527253
# size_parameter is out of range: 0.12648274661103773
# size_parameter is out of range: 0.13340375217617276
# size_parameter is out of range: 0.14070346803434033
# size_parameter is out of range: 0.14840261682254732
# size_parameter is out of range: 0.15652305509914483
# size_parameter is out of range: 0.16508783539083552
# size_parameter is out of range: 0.17412127163482954
# size_parameter is out of range: 0.18364900820192803
# size_parameter is out of range: 0.19369809269647803
# size_parameter is out of range: 0.20429705273986612
# size_parameter is out of range: 0.2154759769555259
# size_parameter is out of range: 0.22726660038536176
# size_parameter is out of range: 0.23970239458007095
# size_parameter is out of range: 0.2528186626191149
# size_parameter is out of range: 0.26665263933008715
# size_parameter is out of range: 0.28124359699197915
# size_parameter is out of range: 0.2966329568224228
# size_parameter is out of range: 0.3128644065653973
# size_parameter is out of range: 0.32998402451321646
# size_parameter is out of range: 542.6279328240003
# size_parameter is out of range: 572.3199741774487
# size_parameter is out of range: 603.6367334387019
# size_parameter is out of range: 636.6671134975475
# size_parameter is out of range: 671.504881918292
# size_parameter is out of range: 708.2489371297412
# size_parameter is out of range: 747.0035891808235
# size_parameter is out of range: 787.8788558588561
# size_parameter is out of range: 830.9907750111207
# size_parameter is out of range: 876.461733956331
# size_parameter is out of range: 924.4208169211702
# size_parameter is out of range: 975.0041714882021
# size_parameter is out of range: 1028.355395095414
# size_parameter is out of range: 1084.6259426846354
# size_parameter is out of range: 1143.9755566560577
# size_parameter is out of range: 1206.572720349401
# size_parameter is out of range: 1272.595136339138
# size_parameter is out of range: 1342.2302309015013
# size_parameter is out of range: 1415.6756860854327
# size_parameter is out of range: 1493.1400008979062
# size_parameter is out of range: 1574.8430831967094
# size_parameter is out of range: 1661.0168739710111
# size_parameter is out of range: 1751.9060057819224
# size_parameter is out of range: 1847.768497232213
# size_parameter is out of range: 1948.876485436744
# size_parameter is out of range: 2055.516998572878
# size_parameter is out of range: 2167.9927707040843
# size_parameter is out of range: 2286.6231011898576
# size_parameter is out of range: 2411.744761121615
# size_parameter is out of range: 2543.7129493579027
# size_parameter is out of range: 2682.902300872792
# size_parameter is out of range: 2829.707950280102
# size_parameter is out of range: 2984.546653552589
# size_parameter is out of range: 3147.8579711203906
# size_parameter is out of range: 3320.105515707449
# size_parameter is out of range: 3501.7782684482704
# size_parameter is out of range: 3693.391967021161
# size_parameter is out of range: 3895.490569738792
# size_parameter is out of range: 4108.647799752176
# size_parameter is out of range: 4333.46877375198
# size_parameter is out of range: 4570.591719790688
# size_parameter is out of range: 4820.689789102144
# size_parameter is out of range: 5084.47296706212
# size_parameter is out of range: 5362.690088714547
# size_parameter is out of range: 5656.130964585343
# size_parameter is out of range: 5987.038754119609
# size_parameter is out of range: 6237.494711960914
# size_parameter is out of range: 6498.428000815819
# size_parameter is out of range: 6770.276919162502
# size_parameter is out of range: 7053.4981008314735
# size_parameter is out of range: 7348.567282028939
# size_parameter is out of range: 7655.980100446954
# size_parameter is out of range: 7976.252927802885
# size_parameter is out of range: 8309.923737206405
# size_parameter is out of range: 8657.553006811204
# size_parameter is out of range: 9019.724661269056
# size_parameter is out of range: 9397.047052567843
# size_parameter is out of range: 9790.153981901021
# size_parameter is out of range: 10199.705764284863
# size_parameter is out of range: 10626.39033771203
# size_parameter is out of range: 11070.92441870422
# size_parameter is out of range: 11534.054706205257
# size_parameter is out of range: 12016.55913583649
# size_parameter is out of range: 12519.248186621693
# size_parameter is out of range: 13042.966242376013
# size_parameter is out of range: 13588.593010046143
# size_parameter is out of range: 14157.044997383784
# size_parameter is out of range: 14749.277052434765
# size_parameter is out of range: 15366.283967429677
# size_parameter is out of range: 16009.102149769962
# size_parameter is out of range: 16678.811362916607
# size_parameter is out of range: 17376.53654010529
# size_parameter is out of range: 18103.44967393492
# size_parameter is out of range: 18860.77178500314
# size_parameter is out of range: 19649.774972896124
# size_parameter is out of range: 20471.78455297715
# size_parameter is out of range: 21328.181282563823
# size_parameter is out of range: 22220.403680232776
# size_parameter is out of range: 23149.950442148027
# size_parameter is out of range: 24118.382959471757
# size_parameter is out of range: 25127.327941085823
# size_parameter is out of range: 26178.480146029695
# size_parameter is out of range: 27273.605230244626
# size_parameter is out of range: 28414.54271240579
# size_parameter is out of range: 29603.20906382388
# size_parameter is out of range: 30841.60092760708
# size_parameter is out of range: 32131.798472489816
# size_parameter is out of range: 33475.96888696288
# size_parameter is out of range: 34876.370019573034
# size_parameter is out of range: 36335.354171507795
# size_parameter is out of range: 37855.37204783537
# size_parameter is out of range: 39438.976874036925
# size_parameter is out of range: 41088.82868474573
# size_parameter is out of range: 42807.69879189744
# size_parameter is out of range: 44598.474439796744
# size_parameter is out of range: 46464.163654919
# size_parameter is out of range: 48407.90029859455
# size_parameter is out of range: 50432.94933106126
# size_parameter is out of range: 52542.71229572914
# size_parameter is out of range: 54740.73303286768
# size_parameter is out of range: 57030.70363231435
# size_parameter is out of range: 59416.47063520306
# size_parameter is out of range: 61902.041495129495
# size_parameter is out of range: 64491.59130960606
# size_parameter is out of range: 67189.46983311532
# size_parameter is out of range: 70000.20878353946
# size_parameter is out of range: 72928.52945423978
# size_parameter is out of range: 75979.35064457377
# size_parameter is out of range: 79157.79692216846
# size_parameter is out of range: 82469.20723083016
# size_parameter is out of range: 85919.14385854929
# size_parameter is out of range: 89513.40178066317
# size_parameter is out of range: 93258.01839387328
# size_parameter is out of range: 97159.28365746433
# size_parameter is out of range: 101223.75065876119

# %%
plt.plot(plot_range,Qe_interp_only)
plt.ylabel('Q2')
plt.xlabel('Dust Geometric Diameter')
plt.xscale('log')
plt.title('Qe at 550 nm for ellipsoidal dust')
# Customize x-axis ticks and labels
plt.xlim(0.2,70)
plt.xticks([0.2, 1, 10, 70], ['0.2', '1', '10', '70'])  # Adjust these values according to your data
plt.show()

# %% [markdown]
# # SSA interpolation

# %%
SSA_interp_matrix_k1 = [] #np.zeros(120, dtype=object)
SSA_interp_matrix_k2 = [] #np.zeros(120, dtype=object)
SSA_interp_matrix_k3 = [] #np.zeros(120, dtype=object)
SSA_interp_only_k1 = []
SSA_interp_only_k2 = []
SSA_interp_only_k3 = []
k_SSA = [0.0005, 0.001, 0.003]
plot_range = []
for i in range(len(diameter_range)):
    size_parameter = np.pi * diameter_range[i] / wavelength_550
    #print(size_parameter)

    if size_parameter < min_size or size_parameter > max_size:
        print("size_parameter is out of range: " +str(size_parameter))
    else:
        #print("size_parameter is within the range.")
        point = np.array([size_parameter, n, k_SSA])
        #Qe_interp = scipy.interpolate.interpn(Yue_coord_matrix, Qe_matrix, point)
        plot_range.append(size_parameter  * wavelength_550 / np.pi)
        for ks in range(len(k_SSA)):
            if ks == 0: 
                SSA_interp = scipy.interpolate.interpn(tuple_array, SSA_matrix,[size_parameter, n, k_SSA[ks]])
                SSA_interp_only_k1.append(SSA_interp[0])
                SSA_interp_matrix_k1.append([size_parameter,n,k_SSA[ks],SSA_interp[0]])
            if ks == 1:
                SSA_interp = scipy.interpolate.interpn(tuple_array, SSA_matrix,[size_parameter, n, k_SSA[ks]])
                SSA_interp_only_k2.append(SSA_interp[0])
                SSA_interp_matrix_k2.append([size_parameter,n,k_SSA[ks],SSA_interp[0]])
            if ks == 2:
                SSA_interp = scipy.interpolate.interpn(tuple_array, SSA_matrix,[size_parameter, n, k_SSA[ks]])
                SSA_interp_only_k3.append(SSA_interp[0])
                SSA_interp_matrix_k3.append([size_parameter,n,k_SSA[ks],SSA_interp[0]])
# Out:
# size_parameter is out of range: 0.028457850282436373
# size_parameter is out of range: 0.03001503452656262
# size_parameter is out of range: 0.031657426287985124
# size_parameter is out of range: 0.03338968803425147
# size_parameter is out of range: 0.03521673735832908
# size_parameter is out of range: 0.03714376093880549
# size_parameter is out of range: 0.03917622926397612
# size_parameter is out of range: 0.04131991216161906
# size_parameter is out of range: 0.043580895178543036
# size_parameter is out of range: 0.0459655968564076
# size_parameter is out of range: 0.048480786952858165
# size_parameter is out of range: 0.05113360565970289
# size_parameter is out of range: 0.05393158387268817
# size_parameter is out of range: 0.05688266457041588
# size_parameter is out of range: 0.05999522536309241
# size_parameter is out of range: 0.06327810227512222
# size_parameter is out of range: 0.06674061482906046
# size_parameter is out of range: 0.07039259250213345
# size_parameter is out of range: 0.07424440263043304
# size_parameter is out of range: 0.07830697983999936
# size_parameter is out of range: 0.08259185708834225
# size_parameter is out of range: 0.08711119840452274
# size_parameter is out of range: 0.0918778334207382
# size_parameter is out of range: 0.09690529379344004
# size_parameter is out of range: 0.10220785161737737
# size_parameter is out of range: 0.10780055994161797
# size_parameter is out of range: 0.11369929550256361
# size_parameter is out of range: 0.11992080379527253
# size_parameter is out of range: 0.12648274661103773
# size_parameter is out of range: 0.13340375217617276
# size_parameter is out of range: 0.14070346803434033
# size_parameter is out of range: 0.14840261682254732
# size_parameter is out of range: 0.15652305509914483
# size_parameter is out of range: 0.16508783539083552
# size_parameter is out of range: 0.17412127163482954
# size_parameter is out of range: 0.18364900820192803
# size_parameter is out of range: 0.19369809269647803
# size_parameter is out of range: 0.20429705273986612
# size_parameter is out of range: 0.2154759769555259
# size_parameter is out of range: 0.22726660038536176
# size_parameter is out of range: 0.23970239458007095
# size_parameter is out of range: 0.2528186626191149
# size_parameter is out of range: 0.26665263933008715
# size_parameter is out of range: 0.28124359699197915
# size_parameter is out of range: 0.2966329568224228
# size_parameter is out of range: 0.3128644065653973
# size_parameter is out of range: 0.32998402451321646
# size_parameter is out of range: 542.6279328240003
# size_parameter is out of range: 572.3199741774487
# size_parameter is out of range: 603.6367334387019
# size_parameter is out of range: 636.6671134975475
# size_parameter is out of range: 671.504881918292
# size_parameter is out of range: 708.2489371297412
# size_parameter is out of range: 747.0035891808235
# size_parameter is out of range: 787.8788558588561
# size_parameter is out of range: 830.9907750111207
# size_parameter is out of range: 876.461733956331
# size_parameter is out of range: 924.4208169211702
# size_parameter is out of range: 975.0041714882021
# size_parameter is out of range: 1028.355395095414
# size_parameter is out of range: 1084.6259426846354
# size_parameter is out of range: 1143.9755566560577
# size_parameter is out of range: 1206.572720349401
# size_parameter is out of range: 1272.595136339138
# size_parameter is out of range: 1342.2302309015013
# size_parameter is out of range: 1415.6756860854327
# size_parameter is out of range: 1493.1400008979062
# size_parameter is out of range: 1574.8430831967094
# size_parameter is out of range: 1661.0168739710111
# size_parameter is out of range: 1751.9060057819224
# size_parameter is out of range: 1847.768497232213
# size_parameter is out of range: 1948.876485436744
# size_parameter is out of range: 2055.516998572878
# size_parameter is out of range: 2167.9927707040843
# size_parameter is out of range: 2286.6231011898576
# size_parameter is out of range: 2411.744761121615
# size_parameter is out of range: 2543.7129493579027
# size_parameter is out of range: 2682.902300872792
# size_parameter is out of range: 2829.707950280102
# size_parameter is out of range: 2984.546653552589
# size_parameter is out of range: 3147.8579711203906
# size_parameter is out of range: 3320.105515707449
# size_parameter is out of range: 3501.7782684482704
# size_parameter is out of range: 3693.391967021161
# size_parameter is out of range: 3895.490569738792
# size_parameter is out of range: 4108.647799752176
# size_parameter is out of range: 4333.46877375198
# size_parameter is out of range: 4570.591719790688
# size_parameter is out of range: 4820.689789102144
# size_parameter is out of range: 5084.47296706212
# size_parameter is out of range: 5362.690088714547
# size_parameter is out of range: 5656.130964585343
# size_parameter is out of range: 5987.038754119609
# size_parameter is out of range: 6237.494711960914
# size_parameter is out of range: 6498.428000815819
# size_parameter is out of range: 6770.276919162502
# size_parameter is out of range: 7053.4981008314735
# size_parameter is out of range: 7348.567282028939
# size_parameter is out of range: 7655.980100446954
# size_parameter is out of range: 7976.252927802885
# size_parameter is out of range: 8309.923737206405
# size_parameter is out of range: 8657.553006811204
# size_parameter is out of range: 9019.724661269056
# size_parameter is out of range: 9397.047052567843
# size_parameter is out of range: 9790.153981901021
# size_parameter is out of range: 10199.705764284863
# size_parameter is out of range: 10626.39033771203
# size_parameter is out of range: 11070.92441870422
# size_parameter is out of range: 11534.054706205257
# size_parameter is out of range: 12016.55913583649
# size_parameter is out of range: 12519.248186621693
# size_parameter is out of range: 13042.966242376013
# size_parameter is out of range: 13588.593010046143
# size_parameter is out of range: 14157.044997383784
# size_parameter is out of range: 14749.277052434765
# size_parameter is out of range: 15366.283967429677
# size_parameter is out of range: 16009.102149769962
# size_parameter is out of range: 16678.811362916607
# size_parameter is out of range: 17376.53654010529
# size_parameter is out of range: 18103.44967393492
# size_parameter is out of range: 18860.77178500314
# size_parameter is out of range: 19649.774972896124
# size_parameter is out of range: 20471.78455297715
# size_parameter is out of range: 21328.181282563823
# size_parameter is out of range: 22220.403680232776
# size_parameter is out of range: 23149.950442148027
# size_parameter is out of range: 24118.382959471757
# size_parameter is out of range: 25127.327941085823
# size_parameter is out of range: 26178.480146029695
# size_parameter is out of range: 27273.605230244626
# size_parameter is out of range: 28414.54271240579
# size_parameter is out of range: 29603.20906382388
# size_parameter is out of range: 30841.60092760708
# size_parameter is out of range: 32131.798472489816
# size_parameter is out of range: 33475.96888696288
# size_parameter is out of range: 34876.370019573034
# size_parameter is out of range: 36335.354171507795
# size_parameter is out of range: 37855.37204783537
# size_parameter is out of range: 39438.976874036925
# size_parameter is out of range: 41088.82868474573
# size_parameter is out of range: 42807.69879189744
# size_parameter is out of range: 44598.474439796744
# size_parameter is out of range: 46464.163654919
# size_parameter is out of range: 48407.90029859455
# size_parameter is out of range: 50432.94933106126
# size_parameter is out of range: 52542.71229572914
# size_parameter is out of range: 54740.73303286768
# size_parameter is out of range: 57030.70363231435
# size_parameter is out of range: 59416.47063520306
# size_parameter is out of range: 61902.041495129495
# size_parameter is out of range: 64491.59130960606
# size_parameter is out of range: 67189.46983311532
# size_parameter is out of range: 70000.20878353946
# size_parameter is out of range: 72928.52945423978
# size_parameter is out of range: 75979.35064457377
# size_parameter is out of range: 79157.79692216846
# size_parameter is out of range: 82469.20723083016
# size_parameter is out of range: 85919.14385854929
# size_parameter is out of range: 89513.40178066317
# size_parameter is out of range: 93258.01839387328
# size_parameter is out of range: 97159.28365746433
# size_parameter is out of range: 101223.75065876119
# /var/folders/47/97wl1v310zqcw6zy080_r_8r0000gs/T/ipykernel_41013/3271951352.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   point = np.array([size_parameter, n, k_SSA])

# %%
plt.plot(plot_range,SSA_interp_only_k1, label='k=0.0005')
plt.plot(plot_range,SSA_interp_only_k2, label='k=0.001')
plt.plot(plot_range,SSA_interp_only_k3, label='k=0.003')
plt.ylabel('SSA')
plt.xlabel('Dust Geometric Diameter')
plt.xscale('log')
plt.xlim(0.2,70)
plt.title('SSA at 550 nm for ellipsoidal dust')
#plt.legend(['k=0.0005', 'k=0.001', 'k=0.003'])
plt.legend()
# Customize x-axis ticks and labels
plt.xticks([0.2, 1, 10, 70], ['0.2', '1', '10', '70'])  # Adjust these values according to your data
# Out:
# ([<matplotlib.axis.XTick at 0x7f9031eba9a0>,
#   <matplotlib.axis.XTick at 0x7f9031eba1f0>,
#   <matplotlib.axis.XTick at 0x7f90208581c0>,
#   <matplotlib.axis.XTick at 0x7f901940e460>],
#  [Text(0.2, 0, '0.2'),
#   Text(1.0, 0, '1'),
#   Text(10.0, 0, '10'),
#   Text(70.0, 0, '70')])

# %% [markdown]
# # g interpolation

# %%
g_interp_matrix = [] #np.zeros(120, dtype=object)
g_interp_only = []
plot_range = []
for i in range(len(diameter_range)):
    size_parameter = np.pi * diameter_range[i] / wavelength_550
    #print(size_parameter)

    if size_parameter < min_size or size_parameter > max_size:
        print("size_parameter is out of range: " +str(size_parameter))
    else:
        #print("size_parameter is within the range.")
        point = np.array([size_parameter, n, k])
        #Qe_interp = scipy.interpolate.interpn(Yue_coord_matrix, Qe_matrix, point)
        plot_range.append(size_parameter  * wavelength_550 / np.pi)
        g_interp = scipy.interpolate.interpn(tuple_array, g_matrix,[size_parameter, n, k])
        g_interp_only.append(g_interp[0])
        g_interp_matrix.append([size_parameter,n,k,g_interp[0]])
# Out:
# size_parameter is out of range: 0.028457850282436373
# size_parameter is out of range: 0.03001503452656262
# size_parameter is out of range: 0.031657426287985124
# size_parameter is out of range: 0.03338968803425147
# size_parameter is out of range: 0.03521673735832908
# size_parameter is out of range: 0.03714376093880549
# size_parameter is out of range: 0.03917622926397612
# size_parameter is out of range: 0.04131991216161906
# size_parameter is out of range: 0.043580895178543036
# size_parameter is out of range: 0.0459655968564076
# size_parameter is out of range: 0.048480786952858165
# size_parameter is out of range: 0.05113360565970289
# size_parameter is out of range: 0.05393158387268817
# size_parameter is out of range: 0.05688266457041588
# size_parameter is out of range: 0.05999522536309241
# size_parameter is out of range: 0.06327810227512222
# size_parameter is out of range: 0.06674061482906046
# size_parameter is out of range: 0.07039259250213345
# size_parameter is out of range: 0.07424440263043304
# size_parameter is out of range: 0.07830697983999936
# size_parameter is out of range: 0.08259185708834225
# size_parameter is out of range: 0.08711119840452274
# size_parameter is out of range: 0.0918778334207382
# size_parameter is out of range: 0.09690529379344004
# size_parameter is out of range: 0.10220785161737737
# size_parameter is out of range: 0.10780055994161797
# size_parameter is out of range: 0.11369929550256361
# size_parameter is out of range: 0.11992080379527253
# size_parameter is out of range: 0.12648274661103773
# size_parameter is out of range: 0.13340375217617276
# size_parameter is out of range: 0.14070346803434033
# size_parameter is out of range: 0.14840261682254732
# size_parameter is out of range: 0.15652305509914483
# size_parameter is out of range: 0.16508783539083552
# size_parameter is out of range: 0.17412127163482954
# size_parameter is out of range: 0.18364900820192803
# size_parameter is out of range: 0.19369809269647803
# size_parameter is out of range: 0.20429705273986612
# size_parameter is out of range: 0.2154759769555259
# size_parameter is out of range: 0.22726660038536176
# size_parameter is out of range: 0.23970239458007095
# size_parameter is out of range: 0.2528186626191149
# size_parameter is out of range: 0.26665263933008715
# size_parameter is out of range: 0.28124359699197915
# size_parameter is out of range: 0.2966329568224228
# size_parameter is out of range: 0.3128644065653973
# size_parameter is out of range: 0.32998402451321646
# size_parameter is out of range: 542.6279328240003
# size_parameter is out of range: 572.3199741774487
# size_parameter is out of range: 603.6367334387019
# size_parameter is out of range: 636.6671134975475
# size_parameter is out of range: 671.504881918292
# size_parameter is out of range: 708.2489371297412
# size_parameter is out of range: 747.0035891808235
# size_parameter is out of range: 787.8788558588561
# size_parameter is out of range: 830.9907750111207
# size_parameter is out of range: 876.461733956331
# size_parameter is out of range: 924.4208169211702
# size_parameter is out of range: 975.0041714882021
# size_parameter is out of range: 1028.355395095414
# size_parameter is out of range: 1084.6259426846354
# size_parameter is out of range: 1143.9755566560577
# size_parameter is out of range: 1206.572720349401
# size_parameter is out of range: 1272.595136339138
# size_parameter is out of range: 1342.2302309015013
# size_parameter is out of range: 1415.6756860854327
# size_parameter is out of range: 1493.1400008979062
# size_parameter is out of range: 1574.8430831967094
# size_parameter is out of range: 1661.0168739710111
# size_parameter is out of range: 1751.9060057819224
# size_parameter is out of range: 1847.768497232213
# size_parameter is out of range: 1948.876485436744
# size_parameter is out of range: 2055.516998572878
# size_parameter is out of range: 2167.9927707040843
# size_parameter is out of range: 2286.6231011898576
# size_parameter is out of range: 2411.744761121615
# size_parameter is out of range: 2543.7129493579027
# size_parameter is out of range: 2682.902300872792
# size_parameter is out of range: 2829.707950280102
# size_parameter is out of range: 2984.546653552589
# size_parameter is out of range: 3147.8579711203906
# size_parameter is out of range: 3320.105515707449
# size_parameter is out of range: 3501.7782684482704
# size_parameter is out of range: 3693.391967021161
# size_parameter is out of range: 3895.490569738792
# size_parameter is out of range: 4108.647799752176
# size_parameter is out of range: 4333.46877375198
# size_parameter is out of range: 4570.591719790688
# size_parameter is out of range: 4820.689789102144
# size_parameter is out of range: 5084.47296706212
# size_parameter is out of range: 5362.690088714547
# size_parameter is out of range: 5656.130964585343
# size_parameter is out of range: 5987.038754119609
# size_parameter is out of range: 6237.494711960914
# size_parameter is out of range: 6498.428000815819
# size_parameter is out of range: 6770.276919162502
# size_parameter is out of range: 7053.4981008314735
# size_parameter is out of range: 7348.567282028939
# size_parameter is out of range: 7655.980100446954
# size_parameter is out of range: 7976.252927802885
# size_parameter is out of range: 8309.923737206405
# size_parameter is out of range: 8657.553006811204
# size_parameter is out of range: 9019.724661269056
# size_parameter is out of range: 9397.047052567843
# size_parameter is out of range: 9790.153981901021
# size_parameter is out of range: 10199.705764284863
# size_parameter is out of range: 10626.39033771203
# size_parameter is out of range: 11070.92441870422
# size_parameter is out of range: 11534.054706205257
# size_parameter is out of range: 12016.55913583649
# size_parameter is out of range: 12519.248186621693
# size_parameter is out of range: 13042.966242376013
# size_parameter is out of range: 13588.593010046143
# size_parameter is out of range: 14157.044997383784
# size_parameter is out of range: 14749.277052434765
# size_parameter is out of range: 15366.283967429677
# size_parameter is out of range: 16009.102149769962
# size_parameter is out of range: 16678.811362916607
# size_parameter is out of range: 17376.53654010529
# size_parameter is out of range: 18103.44967393492
# size_parameter is out of range: 18860.77178500314
# size_parameter is out of range: 19649.774972896124
# size_parameter is out of range: 20471.78455297715
# size_parameter is out of range: 21328.181282563823
# size_parameter is out of range: 22220.403680232776
# size_parameter is out of range: 23149.950442148027
# size_parameter is out of range: 24118.382959471757
# size_parameter is out of range: 25127.327941085823
# size_parameter is out of range: 26178.480146029695
# size_parameter is out of range: 27273.605230244626
# size_parameter is out of range: 28414.54271240579
# size_parameter is out of range: 29603.20906382388
# size_parameter is out of range: 30841.60092760708
# size_parameter is out of range: 32131.798472489816
# size_parameter is out of range: 33475.96888696288
# size_parameter is out of range: 34876.370019573034
# size_parameter is out of range: 36335.354171507795
# size_parameter is out of range: 37855.37204783537
# size_parameter is out of range: 39438.976874036925
# size_parameter is out of range: 41088.82868474573
# size_parameter is out of range: 42807.69879189744
# size_parameter is out of range: 44598.474439796744
# size_parameter is out of range: 46464.163654919
# size_parameter is out of range: 48407.90029859455
# size_parameter is out of range: 50432.94933106126
# size_parameter is out of range: 52542.71229572914
# size_parameter is out of range: 54740.73303286768
# size_parameter is out of range: 57030.70363231435
# size_parameter is out of range: 59416.47063520306
# size_parameter is out of range: 61902.041495129495
# size_parameter is out of range: 64491.59130960606
# size_parameter is out of range: 67189.46983311532
# size_parameter is out of range: 70000.20878353946
# size_parameter is out of range: 72928.52945423978
# size_parameter is out of range: 75979.35064457377
# size_parameter is out of range: 79157.79692216846
# size_parameter is out of range: 82469.20723083016
# size_parameter is out of range: 85919.14385854929
# size_parameter is out of range: 89513.40178066317
# size_parameter is out of range: 93258.01839387328
# size_parameter is out of range: 97159.28365746433
# size_parameter is out of range: 101223.75065876119

# %%
plt.plot(plot_range,g_interp_only)
plt.ylabel('g')
plt.xlabel('Dust Geometric Diameter')
plt.xscale('log')
plt.title('g at 550 nm for ellipsoidal dust')
# Customize x-axis ticks and labels
plt.xlim(0.2,70)
plt.xticks([0.2, 1, 10, 70], ['0.2', '1', '10', '70'])  # Adjust these values according to your data
plt.show()
